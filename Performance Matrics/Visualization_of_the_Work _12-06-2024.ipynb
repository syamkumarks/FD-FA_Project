# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score,roc_curve,recall_score,roc_auc_score,auc,confusion_matrix,cohen_kappa_score, f1_score, precision_score,matthews_corrcoef 
from tqdm import tqdm
from sklearn.svm import SVC,LinearSVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectPercentile, f_classif, chi2, SelectFromModel, SelectKBest
from sklearn.feature_selection import RFE
from sklearn.preprocessing import MinMaxScaler
import scipy.stats as stats
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Optional imports for preprocessing and visualization
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
import pandas as pd
import joblib

# %%
# Set the display options to show all columns
pd.set_option('display.max_columns', None)

# %%
df_rm_base=pd.read_csv("./Radiomics_Features_Base.csv")
df_dl_base=pd.read_csv("./Deep_Learning_Features_Base.csv")

df_rm_aug=pd.read_csv("./Radiomics_Feature_Augmented.csv")
df_dl_aug=pd.read_csv("./Deep_Learning_Features_Augmented.csv")

df_rm_base_Train=pd.read_csv("./Radiomics_Features_Train_Base.csv")
df_dl_base_Train=pd.read_csv("./Deep_Learning_Features_Train_Base.csv")

df_rm_aug_Train=pd.read_csv("./Radiomics_Features_Train_Augmented.csv")
df_dl_aug_Train=pd.read_csv("./Deep_Learning_Features_Train_Augmented.csv")

df_rm_base_Test=pd.read_csv("./Radiomics_Features_Test_Base.csv")
df_dl_base_Test=pd.read_csv("./Deep_Learning_Test_Base.csv")

df_rm_aug_Test=pd.read_csv("./Deep_Learning_Test_Augmented.csv")
df_dl_aug_Test=pd.read_csv("./Radiomics_Features_Test_Augmented.csv")

# %%
print(df_rm_base.shape,df_dl_base.shape,df_rm_aug.shape,df_dl_aug.shape)
print(df_rm_base_Train.shape,df_dl_base_Train.shape,df_rm_aug_Train.shape,df_dl_aug_Train.shape)
print(df_rm_base_Test.shape,df_dl_base_Test.shape,df_rm_aug_Test.shape,df_dl_aug_Test.shape)
# Out:
# (1393, 1221) (1393, 129) (5620, 1220) (5620, 129)
# (1114, 1221) (1114, 129) (4496, 1220) (4496, 129)
# (279, 1221) (279, 128) (1124, 128) (1124, 1220)

# %%
DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

# %% [markdown]
# Base Model  With Five fold Validation Without Oversampling

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score



DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base_Train.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_base_Train['Malignancy']
X_128=df_dl_base_Train.drop(columns='Patient_id')
X_20=df_dl_base_Train[DL_20_top_feature_names]
X_10=df_dl_base_Train[DL_10_top_feature_names]
X_200=df_rm_base_Train[RM_200_top_feature_names]
X_100=df_rm_base_Train[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}



# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}
performance_metrics_Method1 = {}
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
print("## Base Model  With Five fold Validation Without Oversampling ##")
best_model_accuracy = 0
best_model_Name = None
best_model_precision=0
best_model_recall=0
best_model_f1=0
for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    accuracy_scores = []
    precision_scores = []
    recall_scores = []
    f1_scores = []
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
    i=1
    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        

        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train, y_train)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)

    # Check if current model is the best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_precision=precision
            best_recall=recall
            best_f1=f1
            best_model = RF
        
        print(f"Performance of {name} model at Fold {i}: {accuracy:.4f} {precision:.4f} {recall:.4f} {f1:.4f}")
        i=i+1
    print("-" * 30)
# Save the best model
    #joblib.dump(best_model, f'{name}_Base.pkl')
    performance_metrics_Method1[name]=[best_accuracy,best_precision,best_recall,best_f1]
    print(f"Best Performance of {name} model : {best_accuracy:.4f} {best_precision:.4f} {best_recall:.4f} {best_f1:.4f}")
    print("#" * 30)
    if best_accuracy > best_model_accuracy:
           best_model_accuracy= best_accuracy 
           best_model_precision= best_precision
           best_model_recall=best_recall
           best_model_f1=best_f1
           best_model_Name = name
        # Evaluate the model
# Out:
# ## Base Model  With Five fold Validation Without Oversampling ##
# Performance of Radiomics_1218_Feature model at Fold 1: 0.7175 0.5200 0.2031 0.2921
# Performance of Radiomics_1218_Feature model at Fold 2: 0.7175 0.3571 0.0847 0.1370
# Performance of Radiomics_1218_Feature model at Fold 3: 0.7668 0.3571 0.1042 0.1613
# Performance of Radiomics_1218_Feature model at Fold 4: 0.7265 0.4545 0.0833 0.1408
# Performance of Radiomics_1218_Feature model at Fold 5: 0.7523 0.5000 0.2000 0.2857
# ------------------------------
# Best Performance of Radiomics_1218_Feature model : 0.7668 0.3571 0.1042 0.1613
# ##############################
# Performance of Radiomics_200_Features model at Fold 1: 0.6996 0.4286 0.1406 0.2118
# Performance of Radiomics_200_Features model at Fold 2: 0.7265 0.4286 0.1017 0.1644
# Performance of Radiomics_200_Features model at Fold 3: 0.7489 0.2143 0.0625 0.0968
# Performance of Radiomics_200_Features model at Fold 4: 0.7130 0.3571 0.0833 0.1351
# Performance of Radiomics_200_Features model at Fold 5: 0.7613 0.5417 0.2364 0.3291
# ------------------------------
# Best Performance of Radiomics_200_Features model : 0.7613 0.5417 0.2364 0.3291
# ##############################
# Performance of Radiomics_100_Features model at Fold 1: 0.7130 0.5000 0.1250 0.2000
# Performance of Radiomics_100_Features model at Fold 2: 0.7265 0.4375 0.1186 0.1867
# Performance of Radiomics_100_Features model at Fold 3: 0.7623 0.2727 0.0625 0.1017
# Performance of Radiomics_100_Features model at Fold 4: 0.7175 0.3846 0.0833 0.1370
# Performance of Radiomics_100_Features model at Fold 5: 0.7477 0.4783 0.2000 0.2821
# ------------------------------
# Best Performance of Radiomics_100_Features model : 0.7623 0.2727 0.0625 0.1017
# ##############################
# Performance of Fuse_1218_128_Features model at Fold 1: 0.8296 0.7708 0.5781 0.6607
# Performance of Fuse_1218_128_Features model at Fold 2: 0.8520 0.8250 0.5593 0.6667
# Performance of Fuse_1218_128_Features model at Fold 3: 0.9148 0.8718 0.7083 0.7816
# Performance of Fuse_1218_128_Features model at Fold 4: 0.8475 0.7708 0.6167 0.6852
# Performance of Fuse_1218_128_Features model at Fold 5: 0.8919 0.7818 0.7818 0.7818
# ------------------------------
# Best Performance of Fuse_1218_128_Features model : 0.9148 0.8718 0.7083 0.7816
# ##############################
# Performance of Fuse_1218_20_Features model at Fold 1: 0.8072 0.7234 0.5312 0.6126
# Performance of Fuse_1218_20_Features model at Fold 2: 0.8251 0.7632 0.4915 0.5979
# Performance of Fuse_1218_20_Features model at Fold 3: 0.8924 0.7857 0.6875 0.7333
# Performance of Fuse_1218_20_Features model at Fold 4: 0.8341 0.7255 0.6167 0.6667
# Performance of Fuse_1218_20_Features model at Fold 5: 0.8919 0.7818 0.7818 0.7818
# ------------------------------
# Best Performance of Fuse_1218_20_Features model : 0.8924 0.7857 0.6875 0.7333
# ##############################
# Performance of Fuse_1218_10_Features model at Fold 1: 0.8206 0.7857 0.5156 0.6226
# Performance of Fuse_1218_10_Features model at Fold 2: 0.8117 0.7931 0.3898 0.5227
# Performance of Fuse_1218_10_Features model at Fold 3: 0.8520 0.7586 0.4583 0.5714
# Performance of Fuse_1218_10_Features model at Fold 4: 0.8117 0.7647 0.4333 0.5532
# Performance of Fuse_1218_10_Features model at Fold 5: 0.8468 0.7561 0.5636 0.6458
# ------------------------------
# Best Performance of Fuse_1218_10_Features model : 0.8520 0.7586 0.4583 0.5714
# ##############################
# Performance of Fuse_200_128_Features model at Fold 1: 0.8475 0.8125 0.6094 0.6964
# Performance of Fuse_200_128_Features model at Fold 2: 0.8610 0.8043 0.6271 0.7048
# Performance of Fuse_200_128_Features model at Fold 3: 0.9148 0.8537 0.7292 0.7865
# Performance of Fuse_200_128_Features model at Fold 4: 0.8520 0.7455 0.6833 0.7130
# Performance of Fuse_200_128_Features model at Fold 5: 0.8964 0.7581 0.8545 0.8034
# ------------------------------
# Best Performance of Fuse_200_128_Features model : 0.9148 0.8537 0.7292 0.7865
# ##############################
# Performance of Fuse_200_20_Features model at Fold 1: 0.8341 0.7755 0.5938 0.6726
# Performance of Fuse_200_20_Features model at Fold 2: 0.8475 0.7907 0.5763 0.6667
# Performance of Fuse_200_20_Features model at Fold 3: 0.8924 0.7609 0.7292 0.7447
# Performance of Fuse_200_20_Features model at Fold 4: 0.8386 0.7222 0.6500 0.6842
# Performance of Fuse_200_20_Features model at Fold 5: 0.8919 0.7627 0.8182 0.7895
# ------------------------------
# Best Performance of Fuse_200_20_Features model : 0.8924 0.7609 0.7292 0.7447
# ##############################
# Performance of Fuse_200_10_Features model at Fold 1: 0.8206 0.7400 0.5781 0.6491
# Performance of Fuse_200_10_Features model at Fold 2: 0.8341 0.7750 0.5254 0.6263
# Performance of Fuse_200_10_Features model at Fold 3: 0.8924 0.8333 0.6250 0.7143
# Performance of Fuse_200_10_Features model at Fold 4: 0.8251 0.7333 0.5500 0.6286
# Performance of Fuse_200_10_Features model at Fold 5: 0.8874 0.7586 0.8000 0.7788
# ------------------------------
# Best Performance of Fuse_200_10_Features model : 0.8924 0.8333 0.6250 0.7143
# ##############################
# Performance of Fuse_100_128_Features model at Fold 1: 0.8341 0.7872 0.5781 0.6667
# Performance of Fuse_100_128_Features model at Fold 2: 0.8744 0.8444 0.6441 0.7308
# Performance of Fuse_100_128_Features model at Fold 3: 0.9148 0.8537 0.7292 0.7865
# Performance of Fuse_100_128_Features model at Fold 4: 0.8610 0.7636 0.7000 0.7304
# Performance of Fuse_100_128_Features model at Fold 5: 0.9054 0.7833 0.8545 0.8174
# ------------------------------
# Best Performance of Fuse_100_128_Features model : 0.9148 0.8537 0.7292 0.7865
# ##############################
# Performance of Fuse_100_20_Features model at Fold 1: 0.8251 0.7551 0.5781 0.6549
# Performance of Fuse_100_20_Features model at Fold 2: 0.8475 0.7778 0.5932 0.6731
# Performance of Fuse_100_20_Features model at Fold 3: 0.8924 0.7609 0.7292 0.7447
# Performance of Fuse_100_20_Features model at Fold 4: 0.8386 0.7308 0.6333 0.6786
# Performance of Fuse_100_20_Features model at Fold 5: 0.8919 0.7460 0.8545 0.7966
# ------------------------------
# Best Performance of Fuse_100_20_Features model : 0.8924 0.7609 0.7292 0.7447
# ##############################
# Performance of Fuse_100_10_Features model at Fold 1: 0.8296 0.7500 0.6094 0.6724
# Performance of Fuse_100_10_Features model at Fold 2: 0.8341 0.7391 0.5763 0.6476
# Performance of Fuse_100_10_Features model at Fold 3: 0.8924 0.8000 0.6667 0.7273
# Performance of Fuse_100_10_Features model at Fold 4: 0.8386 0.7500 0.6000 0.6667
# Performance of Fuse_100_10_Features model at Fold 5: 0.8874 0.7679 0.7818 0.7748
# ------------------------------
# Best Performance of Fuse_100_10_Features model : 0.8924 0.8000 0.6667 0.7273
# ##############################

# %%
print(f"Best Performance of {best_model_Name} model : {best_model_accuracy:.4f} {best_model_precision:.4f} {best_model_recall:.4f} {best_model_f1:.4f}")
# Out:
# Best Performance of Fuse_1218_128_Features model : 0.9148 0.8718 0.7083 0.7816

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score



DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base_Train.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_base_Train['Malignancy']
X_128=df_dl_base_Train.drop(columns='Patient_id')
scaler = StandardScaler()
X_1218_s = scaler.fit_transform(X_1218)
X_1218 = pd.DataFrame(X_1218_s, columns=X_1218.columns)
X_20=df_dl_base_Train[DL_20_top_feature_names]
X_10=df_dl_base_Train[DL_10_top_feature_names]
X_200=df_rm_base_Train[RM_200_top_feature_names]
X_100=df_rm_base_Train[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}



# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}
performance_metrics_Method2 = {}
print("## Base Model  With Five fold Validation Without Oversampling Standardized ##")
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
    i=1
    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        

        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train, y_train)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)

    # Check if current model is the best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_precision=precision
            best_recall=recall
            best_f1=f1
            best_model = RF
        
        print(f"Performance of {name} model at Fold {i}: {accuracy:.4f} {precision:.4f} {recall:.4f} {f1:.4f}")
        i=i+1
    print("-" * 30)
# Save the best model
    #joblib.dump(best_model, f'{name}_Base.pkl')
    performance_metrics_Method2[name]=[best_accuracy,best_precision,best_recall,best_f1]
    print(f"Best Performance of {name} model : {best_accuracy:.4f} {best_precision:.4f} {best_recall:.4f} {best_f1:.4f}")
    print("#" * 30)
        # Evaluate the model
# Out:
# ## Base Model  With Five fold Validation Without Oversampling Standardized ##
# Performance of Radiomics_1218_Feature model at Fold 1: 0.7354 0.5926 0.2500 0.3516
# Performance of Radiomics_1218_Feature model at Fold 2: 0.7220 0.4000 0.1017 0.1622
# Performance of Radiomics_1218_Feature model at Fold 3: 0.7623 0.3077 0.0833 0.1311
# Performance of Radiomics_1218_Feature model at Fold 4: 0.7309 0.5000 0.1000 0.1667
# Performance of Radiomics_1218_Feature model at Fold 5: 0.7387 0.4286 0.1636 0.2368
# ------------------------------
# Best Performance of Radiomics_1218_Feature model : 0.7623 0.3077 0.0833 0.1311
# ##############################
# Performance of Radiomics_200_Features model at Fold 1: 0.6996 0.4286 0.1406 0.2118
# Performance of Radiomics_200_Features model at Fold 2: 0.7265 0.4286 0.1017 0.1644
# Performance of Radiomics_200_Features model at Fold 3: 0.7489 0.2143 0.0625 0.0968
# Performance of Radiomics_200_Features model at Fold 4: 0.7130 0.3571 0.0833 0.1351
# Performance of Radiomics_200_Features model at Fold 5: 0.7613 0.5417 0.2364 0.3291
# ------------------------------
# Best Performance of Radiomics_200_Features model : 0.7613 0.5417 0.2364 0.3291
# ##############################
# Performance of Radiomics_100_Features model at Fold 1: 0.7130 0.5000 0.1250 0.2000
# Performance of Radiomics_100_Features model at Fold 2: 0.7265 0.4375 0.1186 0.1867
# Performance of Radiomics_100_Features model at Fold 3: 0.7623 0.2727 0.0625 0.1017
# Performance of Radiomics_100_Features model at Fold 4: 0.7175 0.3846 0.0833 0.1370
# Performance of Radiomics_100_Features model at Fold 5: 0.7477 0.4783 0.2000 0.2821
# ------------------------------
# Best Performance of Radiomics_100_Features model : 0.7623 0.2727 0.0625 0.1017
# ##############################
# Performance of Fuse_1218_128_Features model at Fold 1: 0.8341 0.7755 0.5938 0.6726
# Performance of Fuse_1218_128_Features model at Fold 2: 0.8520 0.8250 0.5593 0.6667
# Performance of Fuse_1218_128_Features model at Fold 3: 0.9058 0.8293 0.7083 0.7640
# Performance of Fuse_1218_128_Features model at Fold 4: 0.8475 0.7708 0.6167 0.6852
# Performance of Fuse_1218_128_Features model at Fold 5: 0.8964 0.7963 0.7818 0.7890
# ------------------------------
# Best Performance of Fuse_1218_128_Features model : 0.9058 0.8293 0.7083 0.7640
# ##############################
# Performance of Fuse_1218_20_Features model at Fold 1: 0.8161 0.7347 0.5625 0.6372
# Performance of Fuse_1218_20_Features model at Fold 2: 0.8251 0.7632 0.4915 0.5979
# Performance of Fuse_1218_20_Features model at Fold 3: 0.8879 0.7805 0.6667 0.7191
# Performance of Fuse_1218_20_Features model at Fold 4: 0.8341 0.7255 0.6167 0.6667
# Performance of Fuse_1218_20_Features model at Fold 5: 0.8964 0.7857 0.8000 0.7928
# ------------------------------
# Best Performance of Fuse_1218_20_Features model : 0.8964 0.7857 0.8000 0.7928
# ##############################
# Performance of Fuse_1218_10_Features model at Fold 1: 0.8206 0.7727 0.5312 0.6296
# Performance of Fuse_1218_10_Features model at Fold 2: 0.8072 0.7857 0.3729 0.5057
# Performance of Fuse_1218_10_Features model at Fold 3: 0.8475 0.7500 0.4375 0.5526
# Performance of Fuse_1218_10_Features model at Fold 4: 0.8072 0.7576 0.4167 0.5376
# Performance of Fuse_1218_10_Features model at Fold 5: 0.8378 0.7317 0.5455 0.6250
# ------------------------------
# Best Performance of Fuse_1218_10_Features model : 0.8475 0.7500 0.4375 0.5526
# ##############################
# Performance of Fuse_200_128_Features model at Fold 1: 0.8475 0.8125 0.6094 0.6964
# Performance of Fuse_200_128_Features model at Fold 2: 0.8610 0.8043 0.6271 0.7048
# Performance of Fuse_200_128_Features model at Fold 3: 0.9148 0.8537 0.7292 0.7865
# Performance of Fuse_200_128_Features model at Fold 4: 0.8520 0.7455 0.6833 0.7130
# Performance of Fuse_200_128_Features model at Fold 5: 0.8964 0.7581 0.8545 0.8034
# ------------------------------
# Best Performance of Fuse_200_128_Features model : 0.9148 0.8537 0.7292 0.7865
# ##############################
# Performance of Fuse_200_20_Features model at Fold 1: 0.8341 0.7755 0.5938 0.6726
# Performance of Fuse_200_20_Features model at Fold 2: 0.8475 0.7907 0.5763 0.6667
# Performance of Fuse_200_20_Features model at Fold 3: 0.8924 0.7609 0.7292 0.7447
# Performance of Fuse_200_20_Features model at Fold 4: 0.8386 0.7222 0.6500 0.6842
# Performance of Fuse_200_20_Features model at Fold 5: 0.8919 0.7627 0.8182 0.7895
# ------------------------------
# Best Performance of Fuse_200_20_Features model : 0.8924 0.7609 0.7292 0.7447
# ##############################
# Performance of Fuse_200_10_Features model at Fold 1: 0.8206 0.7400 0.5781 0.6491
# Performance of Fuse_200_10_Features model at Fold 2: 0.8341 0.7750 0.5254 0.6263
# Performance of Fuse_200_10_Features model at Fold 3: 0.8924 0.8333 0.6250 0.7143
# Performance of Fuse_200_10_Features model at Fold 4: 0.8251 0.7333 0.5500 0.6286
# Performance of Fuse_200_10_Features model at Fold 5: 0.8874 0.7586 0.8000 0.7788
# ------------------------------
# Best Performance of Fuse_200_10_Features model : 0.8924 0.8333 0.6250 0.7143
# ##############################
# Performance of Fuse_100_128_Features model at Fold 1: 0.8341 0.7872 0.5781 0.6667
# Performance of Fuse_100_128_Features model at Fold 2: 0.8744 0.8444 0.6441 0.7308
# Performance of Fuse_100_128_Features model at Fold 3: 0.9148 0.8537 0.7292 0.7865
# Performance of Fuse_100_128_Features model at Fold 4: 0.8610 0.7636 0.7000 0.7304
# Performance of Fuse_100_128_Features model at Fold 5: 0.9054 0.7833 0.8545 0.8174
# ------------------------------
# Best Performance of Fuse_100_128_Features model : 0.9148 0.8537 0.7292 0.7865
# ##############################
# Performance of Fuse_100_20_Features model at Fold 1: 0.8251 0.7551 0.5781 0.6549
# Performance of Fuse_100_20_Features model at Fold 2: 0.8475 0.7778 0.5932 0.6731
# Performance of Fuse_100_20_Features model at Fold 3: 0.8924 0.7609 0.7292 0.7447
# Performance of Fuse_100_20_Features model at Fold 4: 0.8386 0.7308 0.6333 0.6786
# Performance of Fuse_100_20_Features model at Fold 5: 0.8919 0.7460 0.8545 0.7966
# ------------------------------
# Best Performance of Fuse_100_20_Features model : 0.8924 0.7609 0.7292 0.7447
# ##############################
# Performance of Fuse_100_10_Features model at Fold 1: 0.8296 0.7500 0.6094 0.6724
# Performance of Fuse_100_10_Features model at Fold 2: 0.8341 0.7391 0.5763 0.6476
# Performance of Fuse_100_10_Features model at Fold 3: 0.8924 0.8000 0.6667 0.7273
# Performance of Fuse_100_10_Features model at Fold 4: 0.8386 0.7500 0.6000 0.6667
# Performance of Fuse_100_10_Features model at Fold 5: 0.8874 0.7679 0.7818 0.7748
# ------------------------------
# Best Performance of Fuse_100_10_Features model : 0.8924 0.8000 0.6667 0.7273
# ##############################

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score



DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base_Train.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_base_Train['Malignancy']
X_128=df_dl_base_Train.drop(columns='Patient_id')
scaler = StandardScaler()
X_1218_s = scaler.fit_transform(X_1218)
X_1218 = pd.DataFrame(X_1218_s, columns=X_1218.columns)
X_20=df_dl_base_Train[DL_20_top_feature_names]
X_10=df_dl_base_Train[DL_10_top_feature_names]
X_200=df_rm_base_Train[RM_200_top_feature_names]
X_100=df_rm_base_Train[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}
best_accuracy = 0
best_model = None
best_precision=0
best_recall=0
best_f1=0
print("## Base Model  With Five fold Validation  Oversampling Before Fold ##")

# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}
performance_metrics_Method3 = {}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
   
    i=1
    oversampler = RandomOverSampler(random_state=42)
    X_resampled, y_resampled = oversampler.fit_resample(X, y)

# Use RandomOverSampler to oversample the minority class

# Standardize the data


# Convert the resampled features and target back to DataFrame for ease of handling
    X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
    y_resampled_df = pd.Series(y_resampled, name='Malignancy')

# Combine the resampled features and target back into a DataFrame
    df_resampled = pd.concat([X_resampled_df, y_resampled_df], axis=1)
    X = df_resampled.drop(columns='Malignancy')
    y = df_resampled['Malignancy']

    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        

        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train, y_train)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)

    # Check if current model is the best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_precision=precision
            best_recall=recall
            best_f1=f1
            best_model = RF
        
        print(f"Performance of {name} model at Fold {i}: {accuracy:.4f} {precision:.4f} {recall:.4f} {f1:.4f}")
        i=i+1
    print("-" * 30)
# Save the best model
    #joblib.dump(best_model, f'{name}_Base.pkl')
    performance_metrics_Method3[name]=[best_accuracy,best_precision,best_recall,best_f1]
    print(f"Best Performance of {name} model : {best_accuracy:.4f} {best_precision:.4f} {best_recall:.4f} {best_f1:.4f}")
    print("#" * 30)
# Out:
# ## Base Model  With Five fold Validation  Oversampling Before Fold ##
# Performance of Radiomics_1218_Feature model at Fold 1: 0.8916 0.8772 0.9091 0.8929
# Performance of Radiomics_1218_Feature model at Fold 2: 0.9154 0.9056 0.9368 0.9209
# Performance of Radiomics_1218_Feature model at Fold 3: 0.9275 0.9281 0.9161 0.9221
# Performance of Radiomics_1218_Feature model at Fold 4: 0.9154 0.8868 0.9338 0.9097
# Performance of Radiomics_1218_Feature model at Fold 5: 0.8731 0.8895 0.8798 0.8846
# ------------------------------
# Best Performance of Radiomics_1218_Feature model : 0.9275 0.9281 0.9161 0.9221
# ##############################
# Performance of Radiomics_200_Features model at Fold 1: 0.8886 0.8721 0.9091 0.8902
# Performance of Radiomics_200_Features model at Fold 2: 0.8973 0.8846 0.9253 0.9045
# Performance of Radiomics_200_Features model at Fold 3: 0.9033 0.8868 0.9097 0.8981
# Performance of Radiomics_200_Features model at Fold 4: 0.9063 0.8704 0.9338 0.9010
# Performance of Radiomics_200_Features model at Fold 5: 0.8822 0.8956 0.8907 0.8932
# ------------------------------
# Best Performance of Radiomics_200_Features model : 0.9063 0.8704 0.9338 0.9010
# ##############################
# Performance of Radiomics_100_Features model at Fold 1: 0.8855 0.8671 0.9091 0.8876
# Performance of Radiomics_100_Features model at Fold 2: 0.9033 0.8817 0.9425 0.9111
# Performance of Radiomics_100_Features model at Fold 3: 0.9094 0.8931 0.9161 0.9045
# Performance of Radiomics_100_Features model at Fold 4: 0.9124 0.8720 0.9470 0.9079
# Performance of Radiomics_100_Features model at Fold 5: 0.8822 0.9000 0.8852 0.8926
# ------------------------------
# Best Performance of Radiomics_100_Features model : 0.9124 0.8720 0.9470 0.9079
# ##############################
# Performance of Fuse_1218_128_Features model at Fold 1: 0.9488 0.9205 0.9818 0.9501
# Performance of Fuse_1218_128_Features model at Fold 2: 0.9517 0.9438 0.9655 0.9545
# Performance of Fuse_1218_128_Features model at Fold 3: 0.9335 0.9030 0.9613 0.9313
# Performance of Fuse_1218_128_Features model at Fold 4: 0.9275 0.8713 0.9868 0.9255
# Performance of Fuse_1218_128_Features model at Fold 5: 0.9456 0.9412 0.9617 0.9514
# ------------------------------
# Best Performance of Fuse_1218_128_Features model : 0.9517 0.9438 0.9655 0.9545
# ##############################
# Performance of Fuse_1218_20_Features model at Fold 1: 0.9337 0.8994 0.9758 0.9360
# Performance of Fuse_1218_20_Features model at Fold 2: 0.9366 0.9180 0.9655 0.9412
# Performance of Fuse_1218_20_Features model at Fold 3: 0.9305 0.9024 0.9548 0.9279
# Performance of Fuse_1218_20_Features model at Fold 4: 0.9154 0.8555 0.9801 0.9136
# Performance of Fuse_1218_20_Features model at Fold 5: 0.9426 0.9409 0.9563 0.9485
# ------------------------------
# Best Performance of Fuse_1218_20_Features model : 0.9426 0.9409 0.9563 0.9485
# ##############################
# Performance of Fuse_1218_10_Features model at Fold 1: 0.9428 0.9148 0.9758 0.9443
# Performance of Fuse_1218_10_Features model at Fold 2: 0.9456 0.9382 0.9598 0.9489
# Performance of Fuse_1218_10_Features model at Fold 3: 0.9366 0.9136 0.9548 0.9338
# Performance of Fuse_1218_10_Features model at Fold 4: 0.9426 0.9074 0.9735 0.9393
# Performance of Fuse_1218_10_Features model at Fold 5: 0.9245 0.9341 0.9290 0.9315
# ------------------------------
# Best Performance of Fuse_1218_10_Features model : 0.9456 0.9382 0.9598 0.9489
# ##############################
# Performance of Fuse_200_128_Features model at Fold 1: 0.9518 0.9209 0.9879 0.9532
# Performance of Fuse_200_128_Features model at Fold 2: 0.9547 0.9441 0.9713 0.9575
# Performance of Fuse_200_128_Features model at Fold 3: 0.9426 0.9198 0.9613 0.9401
# Performance of Fuse_200_128_Features model at Fold 4: 0.9335 0.8817 0.9868 0.9313
# Performance of Fuse_200_128_Features model at Fold 5: 0.9486 0.9368 0.9727 0.9544
# ------------------------------
# Best Performance of Fuse_200_128_Features model : 0.9547 0.9441 0.9713 0.9575
# ##############################
# Performance of Fuse_200_20_Features model at Fold 1: 0.9337 0.8950 0.9818 0.9364
# Performance of Fuse_200_20_Features model at Fold 2: 0.9366 0.9180 0.9655 0.9412
# Performance of Fuse_200_20_Features model at Fold 3: 0.9275 0.8970 0.9548 0.9250
# Performance of Fuse_200_20_Features model at Fold 4: 0.9245 0.8706 0.9801 0.9221
# Performance of Fuse_200_20_Features model at Fold 5: 0.9396 0.9223 0.9727 0.9468
# ------------------------------
# Best Performance of Fuse_200_20_Features model : 0.9396 0.9223 0.9727 0.9468
# ##############################
# Performance of Fuse_200_10_Features model at Fold 1: 0.9337 0.8950 0.9818 0.9364
# Performance of Fuse_200_10_Features model at Fold 2: 0.9396 0.9231 0.9655 0.9438
# Performance of Fuse_200_10_Features model at Fold 3: 0.9335 0.9030 0.9613 0.9313
# Performance of Fuse_200_10_Features model at Fold 4: 0.9275 0.8713 0.9868 0.9255
# Performance of Fuse_200_10_Features model at Fold 5: 0.9486 0.9415 0.9672 0.9542
# ------------------------------
# Best Performance of Fuse_200_10_Features model : 0.9486 0.9415 0.9672 0.9542
# ##############################
# Performance of Fuse_100_128_Features model at Fold 1: 0.9488 0.9157 0.9879 0.9504
# Performance of Fuse_100_128_Features model at Fold 2: 0.9486 0.9290 0.9770 0.9524
# Performance of Fuse_100_128_Features model at Fold 3: 0.9396 0.9091 0.9677 0.9375
# Performance of Fuse_100_128_Features model at Fold 4: 0.9335 0.8817 0.9868 0.9313
# Performance of Fuse_100_128_Features model at Fold 5: 0.9577 0.9519 0.9727 0.9622
# ------------------------------
# Best Performance of Fuse_100_128_Features model : 0.9577 0.9519 0.9727 0.9622
# ##############################
# Performance of Fuse_100_20_Features model at Fold 1: 0.9367 0.8956 0.9879 0.9395
# Performance of Fuse_100_20_Features model at Fold 2: 0.9335 0.9130 0.9655 0.9385
# Performance of Fuse_100_20_Features model at Fold 3: 0.9154 0.8757 0.9548 0.9136
# Performance of Fuse_100_20_Features model at Fold 4: 0.9215 0.8655 0.9801 0.9193
# Performance of Fuse_100_20_Features model at Fold 5: 0.9426 0.9362 0.9617 0.9488
# ------------------------------
# Best Performance of Fuse_100_20_Features model : 0.9426 0.9362 0.9617 0.9488
# ##############################
# Performance of Fuse_100_10_Features model at Fold 1: 0.9307 0.8859 0.9879 0.9341
# Performance of Fuse_100_10_Features model at Fold 2: 0.9366 0.9180 0.9655 0.9412
# Performance of Fuse_100_10_Features model at Fold 3: 0.9245 0.8916 0.9548 0.9221
# Performance of Fuse_100_10_Features model at Fold 4: 0.9275 0.8713 0.9868 0.9255
# Performance of Fuse_100_10_Features model at Fold 5: 0.9426 0.9316 0.9672 0.9491
# ------------------------------
# Best Performance of Fuse_100_10_Features model : 0.9426 0.9316 0.9672 0.9491
# ##############################

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score



DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base_Train.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_base_Train['Malignancy']
X_128=df_dl_base_Train.drop(columns='Patient_id')
X_1218 = pd.DataFrame(X_1218_s, columns=X_1218.columns)
X_20=df_dl_base_Train[DL_20_top_feature_names]
X_10=df_dl_base_Train[DL_10_top_feature_names]
X_200=df_rm_base_Train[RM_200_top_feature_names]
X_100=df_rm_base_Train[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}
best_accuracy = 0
best_model = None
best_precision=0
best_recall=0
best_f1=0

print("## Base Model  With Five fold Validation  Oversampling in Fold ##")
# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}
performance_metrics_Method4 = {}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
   
    i=1
    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        oversampler = RandomOverSampler(random_state=42)
        X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)
        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train_resampled, y_train_resampled)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)

    # Check if current model is the best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_precision=precision
            best_recall=recall
            best_f1=f1
            best_model = RF
        
        print(f"Performance of {name} model at Fold {i}: {accuracy:.4f} {precision:.4f} {recall:.4f} {f1:.4f}")
        i=i+1
    print("-" * 30)
# Save the best model
    #joblib.dump(best_model, f'{name}_Base.pkl')
    performance_metrics_Method4[name]=[best_accuracy,best_precision,best_recall,best_f1]
    print(f"Best Performance of {name} model : {best_accuracy:.4f} {best_precision:.4f} {best_recall:.4f} {best_f1:.4f}")
    print("#" * 30)
# Out:
# ## Base Model  With Five fold Validation  Oversampling in Fold ##
# Performance of Radiomics_1218_Feature model at Fold 1: 0.7175 0.5161 0.2500 0.3368
# Performance of Radiomics_1218_Feature model at Fold 2: 0.7220 0.4118 0.1186 0.1842
# Performance of Radiomics_1218_Feature model at Fold 3: 0.7623 0.3810 0.1667 0.2319
# Performance of Radiomics_1218_Feature model at Fold 4: 0.7220 0.4615 0.2000 0.2791
# Performance of Radiomics_1218_Feature model at Fold 5: 0.7568 0.5152 0.3091 0.3864
# ------------------------------
# Best Performance of Radiomics_1218_Feature model : 0.7623 0.3810 0.1667 0.2319
# ##############################
# Performance of Radiomics_200_Features model at Fold 1: 0.6906 0.4324 0.2500 0.3168
# Performance of Radiomics_200_Features model at Fold 2: 0.7175 0.4167 0.1695 0.2410
# Performance of Radiomics_200_Features model at Fold 3: 0.7489 0.3571 0.2083 0.2632
# Performance of Radiomics_200_Features model at Fold 4: 0.7265 0.4783 0.1833 0.2651
# Performance of Radiomics_200_Features model at Fold 5: 0.7523 0.5000 0.3091 0.3820
# ------------------------------
# Best Performance of Radiomics_200_Features model : 0.7523 0.5000 0.3091 0.3820
# ##############################
# Performance of Radiomics_100_Features model at Fold 1: 0.6816 0.4000 0.2188 0.2828
# Performance of Radiomics_100_Features model at Fold 2: 0.7130 0.4074 0.1864 0.2558
# Performance of Radiomics_100_Features model at Fold 3: 0.7668 0.4167 0.2083 0.2778
# Performance of Radiomics_100_Features model at Fold 4: 0.7175 0.4348 0.1667 0.2410
# Performance of Radiomics_100_Features model at Fold 5: 0.7297 0.4242 0.2545 0.3182
# ------------------------------
# Best Performance of Radiomics_100_Features model : 0.7668 0.4167 0.2083 0.2778
# ##############################
# Performance of Fuse_1218_128_Features model at Fold 1: 0.8565 0.7857 0.6875 0.7333
# Performance of Fuse_1218_128_Features model at Fold 2: 0.8565 0.8000 0.6102 0.6923
# Performance of Fuse_1218_128_Features model at Fold 3: 0.9103 0.8043 0.7708 0.7872
# Performance of Fuse_1218_128_Features model at Fold 4: 0.8520 0.7455 0.6833 0.7130
# Performance of Fuse_1218_128_Features model at Fold 5: 0.8829 0.7458 0.8000 0.7719
# ------------------------------
# Best Performance of Fuse_1218_128_Features model : 0.9103 0.8043 0.7708 0.7872
# ##############################
# Performance of Fuse_1218_20_Features model at Fold 1: 0.8430 0.7636 0.6562 0.7059
# Performance of Fuse_1218_20_Features model at Fold 2: 0.8341 0.7391 0.5763 0.6476
# Performance of Fuse_1218_20_Features model at Fold 3: 0.8879 0.7347 0.7500 0.7423
# Performance of Fuse_1218_20_Features model at Fold 4: 0.8117 0.6667 0.6000 0.6316
# Performance of Fuse_1218_20_Features model at Fold 5: 0.8739 0.7213 0.8000 0.7586
# ------------------------------
# Best Performance of Fuse_1218_20_Features model : 0.8879 0.7347 0.7500 0.7423
# ##############################
# Performance of Fuse_1218_10_Features model at Fold 1: 0.8117 0.7200 0.5625 0.6316
# Performance of Fuse_1218_10_Features model at Fold 2: 0.7803 0.6667 0.3390 0.4494
# Performance of Fuse_1218_10_Features model at Fold 3: 0.8744 0.8125 0.5417 0.6500
# Performance of Fuse_1218_10_Features model at Fold 4: 0.8296 0.7619 0.5333 0.6275
# Performance of Fuse_1218_10_Features model at Fold 5: 0.8333 0.6800 0.6182 0.6476
# ------------------------------
# Best Performance of Fuse_1218_10_Features model : 0.8744 0.8125 0.5417 0.6500
# ##############################
# Performance of Fuse_200_128_Features model at Fold 1: 0.8700 0.7966 0.7344 0.7642
# Performance of Fuse_200_128_Features model at Fold 2: 0.8744 0.8039 0.6949 0.7455
# Performance of Fuse_200_128_Features model at Fold 3: 0.9058 0.8000 0.7500 0.7742
# Performance of Fuse_200_128_Features model at Fold 4: 0.8520 0.7288 0.7167 0.7227
# Performance of Fuse_200_128_Features model at Fold 5: 0.8874 0.7344 0.8545 0.7899
# ------------------------------
# Best Performance of Fuse_200_128_Features model : 0.9058 0.8000 0.7500 0.7742
# ##############################
# Performance of Fuse_200_20_Features model at Fold 1: 0.8430 0.7544 0.6719 0.7107
# Performance of Fuse_200_20_Features model at Fold 2: 0.8520 0.7708 0.6271 0.6916
# Performance of Fuse_200_20_Features model at Fold 3: 0.8834 0.7200 0.7500 0.7347
# Performance of Fuse_200_20_Features model at Fold 4: 0.8430 0.7193 0.6833 0.7009
# Performance of Fuse_200_20_Features model at Fold 5: 0.8829 0.7164 0.8727 0.7869
# ------------------------------
# Best Performance of Fuse_200_20_Features model : 0.8834 0.7200 0.7500 0.7347
# ##############################
# Performance of Fuse_200_10_Features model at Fold 1: 0.8251 0.7193 0.6406 0.6777
# Performance of Fuse_200_10_Features model at Fold 2: 0.8251 0.7174 0.5593 0.6286
# Performance of Fuse_200_10_Features model at Fold 3: 0.8879 0.7674 0.6875 0.7253
# Performance of Fuse_200_10_Features model at Fold 4: 0.8296 0.7037 0.6333 0.6667
# Performance of Fuse_200_10_Features model at Fold 5: 0.8784 0.7333 0.8000 0.7652
# ------------------------------
# Best Performance of Fuse_200_10_Features model : 0.8879 0.7674 0.6875 0.7253
# ##############################
# Performance of Fuse_100_128_Features model at Fold 1: 0.8744 0.8000 0.7500 0.7742
# Performance of Fuse_100_128_Features model at Fold 2: 0.8789 0.8200 0.6949 0.7523
# Performance of Fuse_100_128_Features model at Fold 3: 0.9103 0.8043 0.7708 0.7872
# Performance of Fuse_100_128_Features model at Fold 4: 0.8520 0.7288 0.7167 0.7227
# Performance of Fuse_100_128_Features model at Fold 5: 0.8874 0.7419 0.8364 0.7863
# ------------------------------
# Best Performance of Fuse_100_128_Features model : 0.9103 0.8043 0.7708 0.7872
# ##############################
# Performance of Fuse_100_20_Features model at Fold 1: 0.8475 0.7679 0.6719 0.7167
# Performance of Fuse_100_20_Features model at Fold 2: 0.8565 0.7647 0.6610 0.7091
# Performance of Fuse_100_20_Features model at Fold 3: 0.8789 0.6981 0.7708 0.7327
# Performance of Fuse_100_20_Features model at Fold 4: 0.8475 0.7321 0.6833 0.7069
# Performance of Fuse_100_20_Features model at Fold 5: 0.8784 0.7059 0.8727 0.7805
# ------------------------------
# Best Performance of Fuse_100_20_Features model : 0.8789 0.6981 0.7708 0.7327
# ##############################
# Performance of Fuse_100_10_Features model at Fold 1: 0.8296 0.7167 0.6719 0.6935
# Performance of Fuse_100_10_Features model at Fold 2: 0.8386 0.7347 0.6102 0.6667
# Performance of Fuse_100_10_Features model at Fold 3: 0.9013 0.7955 0.7292 0.7609
# Performance of Fuse_100_10_Features model at Fold 4: 0.8206 0.6852 0.6167 0.6491
# Performance of Fuse_100_10_Features model at Fold 5: 0.8739 0.7143 0.8182 0.7627
# ------------------------------
# Best Performance of Fuse_100_10_Features model : 0.9013 0.7955 0.7292 0.7609
# ##############################

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score



DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_aug_Train.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_aug_Train['Malignancy']
X_128=df_dl_aug_Train.drop(columns='Patient_id')
X_20=df_dl_aug_Train[DL_20_top_feature_names]
X_10=df_dl_aug_Train[DL_10_top_feature_names]
X_200=df_rm_aug_Train[RM_200_top_feature_names]
X_100=df_rm_aug_Train[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}


print("## Augmented Model  With Five fold Validation without Oversampling  ##")
# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}
performance_metrics_Method5 = {}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    accuracy_scores = []
    precision_scores = []
    recall_scores = []
    f1_scores = []
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
    i=1
    for train_index, test_index in cv.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        

        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train, y_train)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)

    # Check if current model is the best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_precision=precision
            best_recall=recall
            best_f1=f1
            best_model = RF
        
        print(f"Performance of {name} model at Fold {i}: {accuracy:.4f} {precision:.4f} {recall:.4f} {f1:.4f}")
        i=i+1
    print("-" * 30)
# Save the best model
    #joblib.dump(best_model, f'{name}_Base.pkl')
    performance_metrics_Method5[name]=[best_accuracy,best_precision,best_recall,best_f1]
    print(f"Best Performance of {name} model : {best_accuracy:.4f} {best_precision:.4f} {best_recall:.4f} {best_f1:.4f}")
    print("#" * 30)
        # Evaluate the model
# Out:
# ## Augmented Model  With Five fold Validation without Oversampling  ##
# Performance of Radiomics_1218_Feature model at Fold 1: 0.8889 0.9710 0.5826 0.7283
# Performance of Radiomics_1218_Feature model at Fold 2: 0.8888 0.9392 0.6043 0.7354
# Performance of Radiomics_1218_Feature model at Fold 3: 0.8910 0.9338 0.6157 0.7421
# Performance of Radiomics_1218_Feature model at Fold 4: 0.8854 0.9565 0.5764 0.7193
# Performance of Radiomics_1218_Feature model at Fold 5: 0.8999 0.9542 0.6376 0.7644
# ------------------------------
# Best Performance of Radiomics_1218_Feature model : 0.8999 0.9542 0.6376 0.7644
# ##############################
# Performance of Radiomics_200_Features model at Fold 1: 0.9311 0.9719 0.7522 0.8480
# Performance of Radiomics_200_Features model at Fold 2: 0.9366 0.9779 0.7696 0.8613
# Performance of Radiomics_200_Features model at Fold 3: 0.9422 0.9683 0.7991 0.8756
# Performance of Radiomics_200_Features model at Fold 4: 0.9433 0.9734 0.7991 0.8777
# Performance of Radiomics_200_Features model at Fold 5: 0.9255 0.9500 0.7467 0.8362
# ------------------------------
# Best Performance of Radiomics_200_Features model : 0.9433 0.9734 0.7991 0.8777
# ##############################
# Performance of Radiomics_100_Features model at Fold 1: 0.9289 0.9716 0.7435 0.8424
# Performance of Radiomics_100_Features model at Fold 2: 0.9355 0.9725 0.7696 0.8592
# Performance of Radiomics_100_Features model at Fold 3: 0.9366 0.9624 0.7817 0.8627
# Performance of Radiomics_100_Features model at Fold 4: 0.9377 0.9626 0.7860 0.8654
# Performance of Radiomics_100_Features model at Fold 5: 0.9299 0.9611 0.7555 0.8460
# ------------------------------
# Best Performance of Radiomics_100_Features model : 0.9377 0.9626 0.7860 0.8654
# ##############################
# Performance of Fuse_1218_128_Features model at Fold 1: 0.8900 0.9712 0.5870 0.7317
# Performance of Fuse_1218_128_Features model at Fold 2: 0.8854 0.9379 0.5913 0.7253
# Performance of Fuse_1218_128_Features model at Fold 3: 0.8943 0.9527 0.6157 0.7480
# Performance of Fuse_1218_128_Features model at Fold 4: 0.8932 0.9716 0.5983 0.7405
# Performance of Fuse_1218_128_Features model at Fold 5: 0.8966 0.9533 0.6245 0.7546
# ------------------------------
# Best Performance of Fuse_1218_128_Features model : 0.8966 0.9533 0.6245 0.7546
# ##############################
# Performance of Fuse_1218_20_Features model at Fold 1: 0.8867 0.9706 0.5739 0.7213
# Performance of Fuse_1218_20_Features model at Fold 2: 0.8910 0.9459 0.6087 0.7407
# Performance of Fuse_1218_20_Features model at Fold 3: 0.8988 0.9313 0.6507 0.7661
# Performance of Fuse_1218_20_Features model at Fold 4: 0.8910 0.9645 0.5939 0.7351
# Performance of Fuse_1218_20_Features model at Fold 5: 0.8954 0.9530 0.6201 0.7513
# ------------------------------
# Best Performance of Fuse_1218_20_Features model : 0.8988 0.9313 0.6507 0.7661
# ##############################
# Performance of Fuse_1218_10_Features model at Fold 1: 0.8922 0.9784 0.5913 0.7371
# Performance of Fuse_1218_10_Features model at Fold 2: 0.8843 0.9375 0.5870 0.7219
# Performance of Fuse_1218_10_Features model at Fold 3: 0.8954 0.9412 0.6288 0.7539
# Performance of Fuse_1218_10_Features model at Fold 4: 0.8899 0.9577 0.5939 0.7332
# Performance of Fuse_1218_10_Features model at Fold 5: 0.9055 0.9557 0.6594 0.7804
# ------------------------------
# Best Performance of Fuse_1218_10_Features model : 0.9055 0.9557 0.6594 0.7804
# ##############################
# Performance of Fuse_200_128_Features model at Fold 1: 0.9133 0.9691 0.6826 0.8010
# Performance of Fuse_200_128_Features model at Fold 2: 0.9199 0.9647 0.7130 0.8200
# Performance of Fuse_200_128_Features model at Fold 3: 0.9177 0.9586 0.7074 0.8141
# Performance of Fuse_200_128_Features model at Fold 4: 0.9255 0.9451 0.7511 0.8370
# Performance of Fuse_200_128_Features model at Fold 5: 0.9199 0.9701 0.7074 0.8182
# ------------------------------
# Best Performance of Fuse_200_128_Features model : 0.9255 0.9451 0.7511 0.8370
# ##############################
# Performance of Fuse_200_20_Features model at Fold 1: 0.9233 0.9653 0.7261 0.8288
# Performance of Fuse_200_20_Features model at Fold 2: 0.9210 0.9704 0.7130 0.8221
# Performance of Fuse_200_20_Features model at Fold 3: 0.9177 0.9480 0.7162 0.8159
# Performance of Fuse_200_20_Features model at Fold 4: 0.9333 0.9774 0.7555 0.8522
# Performance of Fuse_200_20_Features model at Fold 5: 0.9255 0.9655 0.7336 0.8337
# ------------------------------
# Best Performance of Fuse_200_20_Features model : 0.9333 0.9774 0.7555 0.8522
# ##############################
# Performance of Fuse_200_10_Features model at Fold 1: 0.9267 0.9659 0.7391 0.8374
# Performance of Fuse_200_10_Features model at Fold 2: 0.9299 0.9771 0.7435 0.8444
# Performance of Fuse_200_10_Features model at Fold 3: 0.9288 0.9609 0.7511 0.8431
# Performance of Fuse_200_10_Features model at Fold 4: 0.9288 0.9609 0.7511 0.8431
# Performance of Fuse_200_10_Features model at Fold 5: 0.9266 0.9711 0.7336 0.8358
# ------------------------------
# Best Performance of Fuse_200_10_Features model : 0.9299 0.9771 0.7435 0.8444
# ##############################
# Performance of Fuse_100_128_Features model at Fold 1: 0.9022 0.9733 0.6348 0.7684
# Performance of Fuse_100_128_Features model at Fold 2: 0.9043 0.9800 0.6391 0.7737
# Performance of Fuse_100_128_Features model at Fold 3: 0.9021 0.9548 0.6463 0.7708
# Performance of Fuse_100_128_Features model at Fold 4: 0.9021 0.9490 0.6507 0.7720
# Performance of Fuse_100_128_Features model at Fold 5: 0.9021 0.9669 0.6376 0.7684
# ------------------------------
# Best Performance of Fuse_100_128_Features model : 0.9043 0.9800 0.6391 0.7737
# ##############################
# Performance of Fuse_100_20_Features model at Fold 1: 0.9144 0.9636 0.6913 0.8051
# Performance of Fuse_100_20_Features model at Fold 2: 0.9177 0.9756 0.6957 0.8122
# Performance of Fuse_100_20_Features model at Fold 3: 0.9121 0.9464 0.6943 0.8010
# Performance of Fuse_100_20_Features model at Fold 4: 0.9188 0.9643 0.7074 0.8161
# Performance of Fuse_100_20_Features model at Fold 5: 0.9188 0.9643 0.7074 0.8161
# ------------------------------
# Best Performance of Fuse_100_20_Features model : 0.9188 0.9643 0.7074 0.8161
# ##############################
# Performance of Fuse_100_10_Features model at Fold 1: 0.9200 0.9647 0.7130 0.8200
# Performance of Fuse_100_10_Features model at Fold 2: 0.9221 0.9651 0.7217 0.8259
# Performance of Fuse_100_10_Features model at Fold 3: 0.9188 0.9535 0.7162 0.8180
# Performance of Fuse_100_10_Features model at Fold 4: 0.9266 0.9605 0.7424 0.8374
# Performance of Fuse_100_10_Features model at Fold 5: 0.9244 0.9708 0.7249 0.8300
# ------------------------------
# Best Performance of Fuse_100_10_Features model : 0.9266 0.9605 0.7424 0.8374
# ##############################

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score



DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_aug_Train.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_aug_Train['Malignancy']
X_128=df_dl_aug_Train.drop(columns='Patient_id')
scaler = StandardScaler()
X_1218_s = scaler.fit_transform(X_1218)
X_1218 = pd.DataFrame(X_1218_s, columns=X_1218.columns)
X_20=df_dl_aug_Train[DL_20_top_feature_names]
X_10=df_dl_aug_Train[DL_10_top_feature_names]
X_200=df_rm_aug_Train[RM_200_top_feature_names]
X_100=df_rm_aug_Train[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}



# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}
performance_metrics_Method6 = {}

print("## Augmented Model  With Five fold Validation Without Oversampling Standardized ##")
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
    i=1
    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        

        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train, y_train)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)

    # Check if current model is the best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_precision=precision
            best_recall=recall
            best_f1=f1
            best_model = RF
        
        print(f"Performance of {name} model at Fold {i}: {accuracy:.4f} {precision:.4f} {recall:.4f} {f1:.4f}")
        i=i+1
    print("-" * 30)
# Save the best model
    #joblib.dump(best_model, f'{name}_Base.pkl')
    performance_metrics_Method6[name]=[best_accuracy,best_precision,best_recall,best_f1]
    print(f"Best Performance of {name} model : {best_accuracy:.4f} {best_precision:.4f} {best_recall:.4f} {best_f1:.4f}")
    print("#" * 30)
# Out:
# ## Augmented Model  With Five fold Validation Without Oversampling Standardized ##
# Performance of Radiomics_1218_Feature model at Fold 1: 0.9022 0.9474 0.6429 0.7660
# Performance of Radiomics_1218_Feature model at Fold 2: 0.8865 0.9706 0.5739 0.7213
# Performance of Radiomics_1218_Feature model at Fold 3: 0.9066 0.9786 0.6284 0.7654
# Performance of Radiomics_1218_Feature model at Fold 4: 0.8877 0.9714 0.5837 0.7292
# Performance of Radiomics_1218_Feature model at Fold 5: 0.9010 0.9693 0.6529 0.7802
# ------------------------------
# Best Performance of Radiomics_1218_Feature model : 0.9066 0.9786 0.6284 0.7654
# ##############################
# Performance of Radiomics_200_Features model at Fold 1: 0.9433 0.9577 0.8080 0.8765
# Performance of Radiomics_200_Features model at Fold 2: 0.9310 0.9667 0.7565 0.8488
# Performance of Radiomics_200_Features model at Fold 3: 0.9499 0.9676 0.8211 0.8883
# Performance of Radiomics_200_Features model at Fold 4: 0.9377 0.9538 0.7983 0.8692
# Performance of Radiomics_200_Features model at Fold 5: 0.9299 0.9786 0.7562 0.8531
# ------------------------------
# Best Performance of Radiomics_200_Features model : 0.9499 0.9676 0.8211 0.8883
# ##############################
# Performance of Radiomics_100_Features model at Fold 1: 0.9478 0.9634 0.8214 0.8867
# Performance of Radiomics_100_Features model at Fold 2: 0.9366 0.9727 0.7739 0.8620
# Performance of Radiomics_100_Features model at Fold 3: 0.9533 0.9632 0.8394 0.8971
# Performance of Radiomics_100_Features model at Fold 4: 0.9310 0.9622 0.7639 0.8517
# Performance of Radiomics_100_Features model at Fold 5: 0.9310 0.9737 0.7645 0.8565
# ------------------------------
# Best Performance of Radiomics_100_Features model : 0.9533 0.9632 0.8394 0.8971
# ##############################
# Performance of Fuse_1218_128_Features model at Fold 1: 0.9033 0.9536 0.6429 0.7680
# Performance of Fuse_1218_128_Features model at Fold 2: 0.8810 0.9767 0.5478 0.7019
# Performance of Fuse_1218_128_Features model at Fold 3: 0.8966 0.9699 0.5917 0.7350
# Performance of Fuse_1218_128_Features model at Fold 4: 0.8865 0.9580 0.5880 0.7287
# Performance of Fuse_1218_128_Features model at Fold 5: 0.8899 0.9673 0.6116 0.7494
# ------------------------------
# Best Performance of Fuse_1218_128_Features model : 0.9033 0.9536 0.6429 0.7680
# ##############################
# Performance of Fuse_1218_20_Features model at Fold 1: 0.8989 0.9404 0.6339 0.7573
# Performance of Fuse_1218_20_Features model at Fold 2: 0.8865 0.9776 0.5696 0.7198
# Performance of Fuse_1218_20_Features model at Fold 3: 0.8966 0.9699 0.5917 0.7350
# Performance of Fuse_1218_20_Features model at Fold 4: 0.8877 0.9583 0.5923 0.7321
# Performance of Fuse_1218_20_Features model at Fold 5: 0.8966 0.9745 0.6322 0.7669
# ------------------------------
# Best Performance of Fuse_1218_20_Features model : 0.8989 0.9404 0.6339 0.7573
# ##############################
# Performance of Fuse_1218_10_Features model at Fold 1: 0.9022 0.9533 0.6384 0.7647
# Performance of Fuse_1218_10_Features model at Fold 2: 0.8843 0.9632 0.5696 0.7158
# Performance of Fuse_1218_10_Features model at Fold 3: 0.8999 0.9706 0.6055 0.7458
# Performance of Fuse_1218_10_Features model at Fold 4: 0.8888 0.9784 0.5837 0.7312
# Performance of Fuse_1218_10_Features model at Fold 5: 0.8954 0.9744 0.6281 0.7638
# ------------------------------
# Best Performance of Fuse_1218_10_Features model : 0.9022 0.9533 0.6384 0.7647
# ##############################
# Performance of Fuse_200_128_Features model at Fold 1: 0.9267 0.9647 0.7321 0.8325
# Performance of Fuse_200_128_Features model at Fold 2: 0.9143 0.9752 0.6826 0.8031
# Performance of Fuse_200_128_Features model at Fold 3: 0.9310 0.9699 0.7385 0.8385
# Performance of Fuse_200_128_Features model at Fold 4: 0.9288 0.9617 0.7554 0.8462
# Performance of Fuse_200_128_Features model at Fold 5: 0.9155 0.9663 0.7107 0.8190
# ------------------------------
# Best Performance of Fuse_200_128_Features model : 0.9310 0.9699 0.7385 0.8385
# ##############################
# Performance of Fuse_200_20_Features model at Fold 1: 0.9344 0.9609 0.7679 0.8536
# Performance of Fuse_200_20_Features model at Fold 2: 0.9188 0.9816 0.6957 0.8142
# Performance of Fuse_200_20_Features model at Fold 3: 0.9410 0.9714 0.7798 0.8651
# Performance of Fuse_200_20_Features model at Fold 4: 0.9255 0.9560 0.7468 0.8386
# Performance of Fuse_200_20_Features model at Fold 5: 0.9199 0.9722 0.7231 0.8294
# ------------------------------
# Best Performance of Fuse_200_20_Features model : 0.9410 0.9714 0.7798 0.8651
# ##############################
# Performance of Fuse_200_10_Features model at Fold 1: 0.9400 0.9670 0.7857 0.8670
# Performance of Fuse_200_10_Features model at Fold 2: 0.9244 0.9765 0.7217 0.8300
# Performance of Fuse_200_10_Features model at Fold 3: 0.9466 0.9670 0.8073 0.8800
# Performance of Fuse_200_10_Features model at Fold 4: 0.9310 0.9672 0.7597 0.8510
# Performance of Fuse_200_10_Features model at Fold 5: 0.9232 0.9779 0.7314 0.8369
# ------------------------------
# Best Performance of Fuse_200_10_Features model : 0.9466 0.9670 0.8073 0.8800
# ##############################
# Performance of Fuse_100_128_Features model at Fold 1: 0.9178 0.9464 0.7098 0.8112
# Performance of Fuse_100_128_Features model at Fold 2: 0.8954 0.9789 0.6043 0.7473
# Performance of Fuse_100_128_Features model at Fold 3: 0.9077 0.9720 0.6376 0.7701
# Performance of Fuse_100_128_Features model at Fold 4: 0.9021 0.9560 0.6524 0.7755
# Performance of Fuse_100_128_Features model at Fold 5: 0.9043 0.9643 0.6694 0.7902
# ------------------------------
# Best Performance of Fuse_100_128_Features model : 0.9178 0.9464 0.7098 0.8112
# ##############################
# Performance of Fuse_100_20_Features model at Fold 1: 0.9278 0.9595 0.7411 0.8363
# Performance of Fuse_100_20_Features model at Fold 2: 0.9188 0.9701 0.7043 0.8161
# Performance of Fuse_100_20_Features model at Fold 3: 0.9210 0.9623 0.7018 0.8117
# Performance of Fuse_100_20_Features model at Fold 4: 0.9221 0.9605 0.7296 0.8293
# Performance of Fuse_100_20_Features model at Fold 5: 0.9132 0.9659 0.7025 0.8134
# ------------------------------
# Best Performance of Fuse_100_20_Features model : 0.9278 0.9595 0.7411 0.8363
# ##############################
# Performance of Fuse_100_10_Features model at Fold 1: 0.9356 0.9663 0.7679 0.8557
# Performance of Fuse_100_10_Features model at Fold 2: 0.9277 0.9769 0.7348 0.8387
# Performance of Fuse_100_10_Features model at Fold 3: 0.9366 0.9653 0.7661 0.8542
# Performance of Fuse_100_10_Features model at Fold 4: 0.9266 0.9514 0.7554 0.8421
# Performance of Fuse_100_10_Features model at Fold 5: 0.9166 0.9718 0.7107 0.8210
# ------------------------------
# Best Performance of Fuse_100_10_Features model : 0.9366 0.9653 0.7661 0.8542
# ##############################

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score



DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_aug_Train.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_aug_Train['Malignancy']
X_128=df_dl_aug_Train.drop(columns='Patient_id')
scaler = StandardScaler()
X_1218_s = scaler.fit_transform(X_1218)
X_1218 = pd.DataFrame(X_1218_s, columns=X_1218.columns)
X_20=df_dl_aug_Train[DL_20_top_feature_names]
X_10=df_dl_aug_Train[DL_10_top_feature_names]
X_200=df_rm_aug_Train[RM_200_top_feature_names]
X_100=df_rm_aug_Train[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}
best_accuracy = 0
best_model = None
best_precision=0
best_recall=0
best_f1=0
print("## Augmented Model  With Five fold Validation  Oversampling Before Fold ##")

# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}
performance_metrics_Method7 = {}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
   
    i=1
    oversampler = RandomOverSampler(random_state=42)
    X_resampled, y_resampled = oversampler.fit_resample(X, y)

# Use RandomOverSampler to oversample the minority class

# Standardize the data


# Convert the resampled features and target back to DataFrame for ease of handling
    X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
    y_resampled_df = pd.Series(y_resampled, name='Malignancy')

# Combine the resampled features and target back into a DataFrame
    df_resampled = pd.concat([X_resampled_df, y_resampled_df], axis=1)
    X = df_resampled.drop(columns='Malignancy')
    y = df_resampled['Malignancy']

    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        

        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train, y_train)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)

    # Check if current model is the best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_precision=precision
            best_recall=recall
            best_f1=f1
            best_model = RF
        
        print(f"Performance of {name} model at Fold {i}: {accuracy:.4f} {precision:.4f} {recall:.4f} {f1:.4f}")
        i=i+1
    print("-" * 30)
# Save the best model
    #joblib.dump(best_model, f'{name}_Base.pkl')
    performance_metrics_Method7[name]=[best_accuracy,best_precision,best_recall,best_f1]
    print(f"Best Performance of {name} model : {best_accuracy:.4f} {best_precision:.4f} {best_recall:.4f} {best_f1:.4f}")
    print("#" * 30)
# Out:
# ## Augmented Model  With Five fold Validation  Oversampling Before Fold ##
# Performance of Radiomics_1218_Feature model at Fold 1: 0.9828 0.9818 0.9833 0.9825
# Performance of Radiomics_1218_Feature model at Fold 2: 0.9799 0.9791 0.9805 0.9798
# Performance of Radiomics_1218_Feature model at Fold 3: 0.9784 0.9750 0.9822 0.9786
# Performance of Radiomics_1218_Feature model at Fold 4: 0.9858 0.9908 0.9802 0.9855
# Performance of Radiomics_1218_Feature model at Fold 5: 0.9806 0.9825 0.9797 0.9811
# ------------------------------
# Best Performance of Radiomics_1218_Feature model : 0.9858 0.9908 0.9802 0.9855
# ##############################
# Performance of Radiomics_200_Features model at Fold 1: 0.9903 0.9894 0.9909 0.9901
# Performance of Radiomics_200_Features model at Fold 2: 0.9858 0.9865 0.9850 0.9858
# Performance of Radiomics_200_Features model at Fold 3: 0.9784 0.9682 0.9896 0.9788
# Performance of Radiomics_200_Features model at Fold 4: 0.9903 0.9864 0.9939 0.9902
# Performance of Radiomics_200_Features model at Fold 5: 0.9918 0.9913 0.9927 0.9920
# ------------------------------
# Best Performance of Radiomics_200_Features model : 0.9918 0.9913 0.9927 0.9920
# ##############################
# Performance of Radiomics_100_Features model at Fold 1: 0.9896 0.9835 0.9954 0.9894
# Performance of Radiomics_100_Features model at Fold 2: 0.9873 0.9895 0.9850 0.9872
# Performance of Radiomics_100_Features model at Fold 3: 0.9799 0.9696 0.9911 0.9802
# Performance of Radiomics_100_Features model at Fold 4: 0.9888 0.9835 0.9939 0.9887
# Performance of Radiomics_100_Features model at Fold 5: 0.9910 0.9927 0.9898 0.9913
# ------------------------------
# Best Performance of Radiomics_100_Features model : 0.9910 0.9927 0.9898 0.9913
# ##############################
# Performance of Fuse_1218_128_Features model at Fold 1: 0.9828 0.9789 0.9863 0.9826
# Performance of Fuse_1218_128_Features model at Fold 2: 0.9791 0.9762 0.9820 0.9791
# Performance of Fuse_1218_128_Features model at Fold 3: 0.9769 0.9722 0.9822 0.9772
# Performance of Fuse_1218_128_Features model at Fold 4: 0.9851 0.9863 0.9833 0.9848
# Performance of Fuse_1218_128_Features model at Fold 5: 0.9791 0.9797 0.9797 0.9797
# ------------------------------
# Best Performance of Fuse_1218_128_Features model : 0.9851 0.9863 0.9833 0.9848
# ##############################
# Performance of Fuse_1218_20_Features model at Fold 1: 0.9813 0.9759 0.9863 0.9811
# Performance of Fuse_1218_20_Features model at Fold 2: 0.9791 0.9790 0.9790 0.9790
# Performance of Fuse_1218_20_Features model at Fold 3: 0.9776 0.9736 0.9822 0.9779
# Performance of Fuse_1218_20_Features model at Fold 4: 0.9843 0.9892 0.9787 0.9840
# Performance of Fuse_1218_20_Features model at Fold 5: 0.9821 0.9854 0.9797 0.9825
# ------------------------------
# Best Performance of Fuse_1218_20_Features model : 0.9843 0.9892 0.9787 0.9840
# ##############################
# Performance of Fuse_1218_10_Features model at Fold 1: 0.9828 0.9833 0.9818 0.9825
# Performance of Fuse_1218_10_Features model at Fold 2: 0.9806 0.9791 0.9820 0.9806
# Performance of Fuse_1218_10_Features model at Fold 3: 0.9776 0.9764 0.9793 0.9778
# Performance of Fuse_1218_10_Features model at Fold 4: 0.9851 0.9878 0.9818 0.9848
# Performance of Fuse_1218_10_Features model at Fold 5: 0.9783 0.9783 0.9797 0.9790
# ------------------------------
# Best Performance of Fuse_1218_10_Features model : 0.9851 0.9878 0.9818 0.9848
# ##############################
# Performance of Fuse_200_128_Features model at Fold 1: 0.9888 0.9864 0.9909 0.9886
# Performance of Fuse_200_128_Features model at Fold 2: 0.9821 0.9777 0.9865 0.9821
# Performance of Fuse_200_128_Features model at Fold 3: 0.9813 0.9752 0.9882 0.9816
# Performance of Fuse_200_128_Features model at Fold 4: 0.9866 0.9834 0.9894 0.9864
# Performance of Fuse_200_128_Features model at Fold 5: 0.9881 0.9912 0.9855 0.9884
# ------------------------------
# Best Performance of Fuse_200_128_Features model : 0.9888 0.9864 0.9909 0.9886
# ##############################
# Performance of Fuse_200_20_Features model at Fold 1: 0.9896 0.9864 0.9924 0.9894
# Performance of Fuse_200_20_Features model at Fold 2: 0.9843 0.9807 0.9880 0.9843
# Performance of Fuse_200_20_Features model at Fold 3: 0.9791 0.9696 0.9896 0.9795
# Performance of Fuse_200_20_Features model at Fold 4: 0.9873 0.9849 0.9894 0.9871
# Performance of Fuse_200_20_Features model at Fold 5: 0.9903 0.9927 0.9884 0.9905
# ------------------------------
# Best Performance of Fuse_200_20_Features model : 0.9903 0.9927 0.9884 0.9905
# ##############################
# Performance of Fuse_200_10_Features model at Fold 1: 0.9910 0.9894 0.9924 0.9909
# Performance of Fuse_200_10_Features model at Fold 2: 0.9843 0.9821 0.9865 0.9843
# Performance of Fuse_200_10_Features model at Fold 3: 0.9806 0.9724 0.9896 0.9809
# Performance of Fuse_200_10_Features model at Fold 4: 0.9910 0.9850 0.9970 0.9909
# Performance of Fuse_200_10_Features model at Fold 5: 0.9918 0.9927 0.9913 0.9920
# ------------------------------
# Best Performance of Fuse_200_10_Features model : 0.9918 0.9927 0.9913 0.9920
# ##############################
# Performance of Fuse_100_128_Features model at Fold 1: 0.9843 0.9775 0.9909 0.9842
# Performance of Fuse_100_128_Features model at Fold 2: 0.9843 0.9836 0.9850 0.9843
# Performance of Fuse_100_128_Features model at Fold 3: 0.9806 0.9738 0.9882 0.9809
# Performance of Fuse_100_128_Features model at Fold 4: 0.9843 0.9833 0.9848 0.9841
# Performance of Fuse_100_128_Features model at Fold 5: 0.9843 0.9855 0.9840 0.9847
# ------------------------------
# Best Performance of Fuse_100_128_Features model : 0.9843 0.9775 0.9909 0.9842
# ##############################
# Performance of Fuse_100_20_Features model at Fold 1: 0.9866 0.9790 0.9939 0.9864
# Performance of Fuse_100_20_Features model at Fold 2: 0.9806 0.9763 0.9850 0.9806
# Performance of Fuse_100_20_Features model at Fold 3: 0.9806 0.9738 0.9882 0.9809
# Performance of Fuse_100_20_Features model at Fold 4: 0.9881 0.9864 0.9894 0.9879
# Performance of Fuse_100_20_Features model at Fold 5: 0.9873 0.9884 0.9869 0.9877
# ------------------------------
# Best Performance of Fuse_100_20_Features model : 0.9881 0.9864 0.9894 0.9879
# ##############################
# Performance of Fuse_100_10_Features model at Fold 1: 0.9896 0.9864 0.9924 0.9894
# Performance of Fuse_100_10_Features model at Fold 2: 0.9851 0.9836 0.9865 0.9851
# Performance of Fuse_100_10_Features model at Fold 3: 0.9806 0.9738 0.9882 0.9809
# Performance of Fuse_100_10_Features model at Fold 4: 0.9873 0.9834 0.9909 0.9871
# Performance of Fuse_100_10_Features model at Fold 5: 0.9888 0.9898 0.9884 0.9891
# ------------------------------
# Best Performance of Fuse_100_10_Features model : 0.9896 0.9864 0.9924 0.9894
# ##############################

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score



DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_aug_Train.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_aug_Train['Malignancy']
X_128=df_dl_aug_Train.drop(columns='Patient_id')
X_1218 = pd.DataFrame(X_1218_s, columns=X_1218.columns)
X_20=df_dl_aug_Train[DL_20_top_feature_names]
X_10=df_dl_aug_Train[DL_10_top_feature_names]
X_200=df_rm_aug_Train[RM_200_top_feature_names]
X_100=df_rm_aug_Train[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}
best_accuracy = 0
best_model = None
best_precision=0
best_recall=0
best_f1=0

print("## Augmented Model  With Five fold Validation  Oversampling in Fold ##")
# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}
performance_metrics_Method8 = {}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    best_accuracy = 0
    best_model = None
    best_precision=0
    best_recall=0
    best_f1=0
   
    i=1
    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        oversampler = RandomOverSampler(random_state=42)
        X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)
        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train_resampled, y_train_resampled)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)

    # Check if current model is the best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_precision=precision
            best_recall=recall
            best_f1=f1
            best_model = RF
        
        #print(f"Performance of {name} model at Fold {i}: {accuracy:.4f} {precision:.4f} {recall:.4f} {f1:.4f}")
        i=i+1
    print("-" * 30)
# Save the best model
    #joblib.dump(best_model, f'{name}_Base.pkl')
    performance_metrics_Method8[name]=[best_accuracy,best_precision,best_recall,best_f1]
    print(f"Best Performance of {name} model : {best_accuracy:.4f} {best_precision:.4f} {best_recall:.4f} {best_f1:.4f}")
    print("#" * 30)
# Out:
# ## Augmented Model  With Five fold Validation  Oversampling in Fold ##
# Performance of Radiomics_1218_Feature model at Fold 1: 0.9311 0.9175 0.7946 0.8517
# Performance of Radiomics_1218_Feature model at Fold 2: 0.9099 0.9461 0.6870 0.7960
# Performance of Radiomics_1218_Feature model at Fold 3: 0.9388 0.9553 0.7844 0.8615
# Performance of Radiomics_1218_Feature model at Fold 4: 0.9232 0.9505 0.7425 0.8337
# Performance of Radiomics_1218_Feature model at Fold 5: 0.9043 0.9333 0.6942 0.7962
# ------------------------------
# Best Performance of Radiomics_1218_Feature model : 0.9388 0.9553 0.7844 0.8615
# ##############################
# Performance of Radiomics_200_Features model at Fold 1: 0.9622 0.9524 0.8929 0.9217
# Performance of Radiomics_200_Features model at Fold 2: 0.9522 0.9698 0.8391 0.8998
# Performance of Radiomics_200_Features model at Fold 3: 0.9644 0.9697 0.8807 0.9231
# Performance of Radiomics_200_Features model at Fold 4: 0.9588 0.9455 0.8927 0.9183
# Performance of Radiomics_200_Features model at Fold 5: 0.9366 0.9512 0.8058 0.8725
# ------------------------------
# Best Performance of Radiomics_200_Features model : 0.9644 0.9697 0.8807 0.9231
# ##############################
# Performance of Radiomics_100_Features model at Fold 1: 0.9644 0.9571 0.8973 0.9263
# Performance of Radiomics_100_Features model at Fold 2: 0.9522 0.9698 0.8391 0.8998
# Performance of Radiomics_100_Features model at Fold 3: 0.9644 0.9650 0.8853 0.9234
# Performance of Radiomics_100_Features model at Fold 4: 0.9555 0.9488 0.8755 0.9107
# Performance of Radiomics_100_Features model at Fold 5: 0.9399 0.9563 0.8140 0.8795
# ------------------------------
# Best Performance of Radiomics_100_Features model : 0.9644 0.9571 0.8973 0.9263
# ##############################
# Performance of Fuse_1218_128_Features model at Fold 1: 0.9256 0.9337 0.7545 0.8346
# Performance of Fuse_1218_128_Features model at Fold 2: 0.9099 0.9515 0.6826 0.7949
# Performance of Fuse_1218_128_Features model at Fold 3: 0.9366 0.9497 0.7798 0.8564
# Performance of Fuse_1218_128_Features model at Fold 4: 0.9210 0.9402 0.7425 0.8297
# Performance of Fuse_1218_128_Features model at Fold 5: 0.9021 0.9278 0.6901 0.7915
# ------------------------------
# Best Performance of Fuse_1218_128_Features model : 0.9366 0.9497 0.7798 0.8564
# ##############################
# Performance of Fuse_1218_20_Features model at Fold 1: 0.9244 0.9239 0.7589 0.8333
# Performance of Fuse_1218_20_Features model at Fold 2: 0.9155 0.9639 0.6957 0.8081
# Performance of Fuse_1218_20_Features model at Fold 3: 0.9355 0.9545 0.7706 0.8528
# Performance of Fuse_1218_20_Features model at Fold 4: 0.9288 0.9568 0.7597 0.8469
# Performance of Fuse_1218_20_Features model at Fold 5: 0.9066 0.9247 0.7107 0.8037
# ------------------------------
# Best Performance of Fuse_1218_20_Features model : 0.9355 0.9545 0.7706 0.8528
# ##############################
# Performance of Fuse_1218_10_Features model at Fold 1: 0.9300 0.9399 0.7679 0.8452
# Performance of Fuse_1218_10_Features model at Fold 2: 0.9155 0.9425 0.7130 0.8119
# Performance of Fuse_1218_10_Features model at Fold 3: 0.9333 0.9489 0.7661 0.8477
# Performance of Fuse_1218_10_Features model at Fold 4: 0.9210 0.9451 0.7382 0.8289
# Performance of Fuse_1218_10_Features model at Fold 5: 0.9077 0.9297 0.7107 0.8056
# ------------------------------
# Best Performance of Fuse_1218_10_Features model : 0.9333 0.9489 0.7661 0.8477
# ##############################
# Performance of Fuse_200_128_Features model at Fold 1: 0.9511 0.9455 0.8527 0.8967
# Performance of Fuse_200_128_Features model at Fold 2: 0.9488 0.9742 0.8217 0.8915
# Performance of Fuse_200_128_Features model at Fold 3: 0.9566 0.9590 0.8578 0.9056
# Performance of Fuse_200_128_Features model at Fold 4: 0.9511 0.9437 0.8627 0.9013
# Performance of Fuse_200_128_Features model at Fold 5: 0.9310 0.9500 0.7851 0.8597
# ------------------------------
# Best Performance of Fuse_200_128_Features model : 0.9566 0.9590 0.8578 0.9056
# ##############################
# Performance of Fuse_200_20_Features model at Fold 1: 0.9544 0.9420 0.8705 0.9049
# Performance of Fuse_200_20_Features model at Fold 2: 0.9499 0.9695 0.8304 0.8946
# Performance of Fuse_200_20_Features model at Fold 3: 0.9555 0.9588 0.8532 0.9029
# Performance of Fuse_200_20_Features model at Fold 4: 0.9555 0.9447 0.8798 0.9111
# Performance of Fuse_200_20_Features model at Fold 5: 0.9266 0.9490 0.7686 0.8493
# ------------------------------
# Best Performance of Fuse_200_20_Features model : 0.9555 0.9588 0.8532 0.9029
# ##############################
# Performance of Fuse_200_10_Features model at Fold 1: 0.9600 0.9393 0.8973 0.9178
# Performance of Fuse_200_10_Features model at Fold 2: 0.9477 0.9552 0.8348 0.8910
# Performance of Fuse_200_10_Features model at Fold 3: 0.9633 0.9695 0.8761 0.9205
# Performance of Fuse_200_10_Features model at Fold 4: 0.9566 0.9491 0.8798 0.9131
# Performance of Fuse_200_10_Features model at Fold 5: 0.9355 0.9510 0.8017 0.8700
# ------------------------------
# Best Performance of Fuse_200_10_Features model : 0.9633 0.9695 0.8761 0.9205
# ##############################
# Performance of Fuse_100_128_Features model at Fold 1: 0.9433 0.9436 0.8214 0.8783
# Performance of Fuse_100_128_Features model at Fold 2: 0.9410 0.9585 0.8043 0.8747
# Performance of Fuse_100_128_Features model at Fold 3: 0.9466 0.9474 0.8257 0.8824
# Performance of Fuse_100_128_Features model at Fold 4: 0.9477 0.9429 0.8498 0.8939
# Performance of Fuse_100_128_Features model at Fold 5: 0.9244 0.9439 0.7645 0.8447
# ------------------------------
# Best Performance of Fuse_100_128_Features model : 0.9477 0.9429 0.8498 0.8939
# ##############################
# Performance of Fuse_100_20_Features model at Fold 1: 0.9511 0.9500 0.8482 0.8962
# Performance of Fuse_100_20_Features model at Fold 2: 0.9477 0.9645 0.8261 0.8899
# Performance of Fuse_100_20_Features model at Fold 3: 0.9522 0.9487 0.8486 0.8959
# Performance of Fuse_100_20_Features model at Fold 4: 0.9511 0.9479 0.8584 0.9009
# Performance of Fuse_100_20_Features model at Fold 5: 0.9244 0.9350 0.7727 0.8462
# ------------------------------
# Best Performance of Fuse_100_20_Features model : 0.9522 0.9487 0.8486 0.8959
# ##############################
# Performance of Fuse_100_10_Features model at Fold 1: 0.9578 0.9515 0.8750 0.9116
# Performance of Fuse_100_10_Features model at Fold 2: 0.9499 0.9695 0.8304 0.8946
# Performance of Fuse_100_10_Features model at Fold 3: 0.9600 0.9643 0.8670 0.9130
# Performance of Fuse_100_10_Features model at Fold 4: 0.9544 0.9486 0.8712 0.9083
# Performance of Fuse_100_10_Features model at Fold 5: 0.9366 0.9602 0.7975 0.8713
# ------------------------------
# Best Performance of Fuse_100_10_Features model : 0.9600 0.9643 0.8670 0.9130
# ##############################

# %%
performance_metrics_Method8
# Out:
# {'Radiomics_1218_Feature': [0.9858103061986557,
#   0.9907834101382489,
#   0.9802431610942249,
#   0.985485103132162],
#  'Radiomics_200_Features': [0.9917849141150112,
#   0.991304347826087,
#   0.9927431059506531,
#   0.9920232052211748],
#  'Radiomics_100_Features': [0.9910380881254668,
#   0.992721979621543,
#   0.9898403483309144,
#   0.9912790697674418],
#  'Fuse_1218_128_Features': [0.9850634802091113,
#   0.9862804878048781,
#   0.9832826747720365,
#   0.984779299847793],
#  'Fuse_1218_20_Features': [0.9843166542195668,
#   0.989247311827957,
#   0.9787234042553191,
#   0.983957219251337],
#  'Fuse_1218_10_Features': [0.9850634802091113,
#   0.9877675840978594,
#   0.9817629179331308,
#   0.9847560975609756],
#  'Fuse_200_128_Features': [0.9888059701492538,
#   0.9863842662632375,
#   0.9908814589665653,
#   0.9886277482941622],
#  'Fuse_200_20_Features': [0.9902912621359223,
#   0.9927113702623906,
#   0.988388969521045,
#   0.9905454545454545],
#  'Fuse_200_10_Features': [0.9917849141150112,
#   0.9927325581395349,
#   0.9912917271407837,
#   0.9920116194625999],
#  'Fuse_100_128_Features': [0.9843283582089553,
#   0.9775112443778111,
#   0.9908814589665653,
#   0.9841509433962264],
#  'Fuse_100_20_Features': [0.988050784167289,
#   0.9863636363636363,
#   0.9893617021276596,
#   0.9878603945371776],
#  'Fuse_100_10_Features': [0.9895522388059701,
#   0.986404833836858,
#   0.9924012158054711,
#   0.9893939393939394]}
