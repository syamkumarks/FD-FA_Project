# %%
Final_Train_accuracy_Base={'RM 1218 DL 128 Features': 0.9516616314199395,
 'RM 200 and 128 DL Features': 0.9577039274924471,
 'RM 100 and 128 DL Features': 0.9607250755287009,
 'RM 1218 and 20 DL Features': 0.9486404833836858,
 'RM 1218 and 10 DL Features': 0.9395770392749244,
 'RM 200 and 20 DL Features': 0.9516616314199395,
 'RM 200 and 10 DL Features': 0.9516616314199395,
 'RM 100 and 20 DL Features': 0.9516616314199395,
 'RM 100 and 10 DL Features': 0.9486404833836858}
Final_Test_accuracy_Base={'RM 1218 DL 128 Features ': 0.8673835125448028,
 'RM 200 and 128 DL Features': 0.9032258064516129,
 'RM 100 and 128 DL Features': 0.921146953405018,
 'RM 1218 and 20 DL Features': 0.899641577060932,
 'RM 1218 and 10 DL Features': 0.8745519713261649,
 'RM 200 and 20 DL Features': 0.9068100358422939,
 'RM 200 and 10 DL Features': 0.8888888888888888,
 'RM 100 and 20 DL Features': 0.899641577060932,
  'RM 100 and 10 DL Features':0.8888888888888888}

Final_Train_accuracy_Augmented={'RM 1218 DL 128 Features': 0.9686333084391336,
 'RM 200 and 128 DL Features': 0.9895522388059701,
 'RM 100 and 128 DL Features': 0.9858103061986557,
 'RM 1218 and 20 DL Features': 0.9843166542195668,
 'RM 1218 and 10 DL Features': 0.9835698282300224,
 'RM 200 and 20 DL Features': 0.9895522388059701,
 'RM 200 and 10 DL Features': 0.9902985074626866,
 'RM 100 and 20 DL Features': 0.9888059701492538,
 'RM 100 and 10 DL Features': 0.9887976101568334}

Final_Test_accuracy_Augmented={'RM 1218 and 128 DL Features': 0.797153024911032,
 'RM 200 and 128 DL Features': 0.952846975088968,
 'RM 100 and 128 DL Features': 0.9448398576512456,
 'RM 1218 and 20 DL Features ': 0.9421708185053381,
 'RM 1218 and 10 DL Features ': 0.943950177935943,
 'RM 200 and 20 DL Features': 0.9564056939501779,
 'RM 200 and 10 DL Features': 0.9599644128113879,
 'RM 100 and 20 DL Feature': 0.9555160142348754,
 'RM 100 and 10 DL Features': 0.9555160142348754}

# %%
import matplotlib.pyplot as plt

# Data
x_values = list(Final_Train_accuracy_Base.keys())
y_train_base = list(Final_Train_accuracy_Base.values())
y_test_base = list(Final_Test_accuracy_Base.values())
y_train_augmented = list(Final_Train_accuracy_Augmented.values())
y_test_augmented = list(Final_Test_accuracy_Augmented.values())

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the lines
ax.plot(x_values, y_train_base, label='Train Accuracy (Base)', marker='o')
ax.plot(x_values, y_test_base, label='Test Accuracy (Base)', marker='o')
ax.plot(x_values, y_train_augmented, label='Train Accuracy (Augmented)', marker='o')
ax.plot(x_values, y_test_augmented, label='Test Accuracy (Augmented)', marker='o')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Add labels and title
ax.set_xlabel('Model Configuration')
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy Comparison')

# Add legend
ax.legend()

# Add annotations
for i, (x, y_train_base, y_test_base, y_train_augmented, y_test_augmented) in enumerate(zip(x_values, y_train_base, y_test_base, y_train_augmented, y_test_augmented)):
    ax.annotate(f'Train: {y_train_base:.4f}\nTest: {y_test_base:.4f}', (x, y_train_base), xytext=(10, 10), textcoords='offset points', ha='left', va='bottom')
    ax.annotate(f'Train: {y_train_augmented:.4f}\nTest: {y_test_augmented:.4f}', (x, y_train_augmented), xytext=(10, -20), textcoords='offset points', ha='left', va='top')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x_values = list(Final_Train_accuracy_Base.keys())
y_train_base = list(Final_Train_accuracy_Base.values())
y_test_base = list(Final_Test_accuracy_Base.values())
y_train_augmented = list(Final_Train_accuracy_Augmented.values())
y_test_augmented = list(Final_Test_accuracy_Augmented.values())

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the lines
ax.plot(x_values, y_train_base, label='Train Accuracy (Base)', marker='o', color='r')
ax.plot(x_values, y_test_base, label='Test Accuracy (Base)', marker='o', color='b')
ax.plot(x_values, y_train_augmented, label='Train Accuracy (Augmented)', marker='o', color='g')
ax.plot(x_values, y_test_augmented, label='Test Accuracy (Augmented)', marker='o', color='y')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Add labels and title
ax.set_xlabel('Model Configuration')
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy Comparison')

# Add legend
ax.legend()

# Add annotations
for i, (x, y_train_base, y_test_base) in enumerate(zip(x_values, y_train_base, y_test_base)):
    ax.annotate(f'Train: {y_train_base:.4f}', (x, y_train_base), xytext=(10, 5), textcoords='offset points', ha='left', va='bottom', color='r')
    ax.annotate(f'Test: {y_test_base:.4f}', (x, y_test_base), xytext=(10, -5), textcoords='offset points', ha='left', va='top', color='b')

for i, (x, y_train_augmented, y_test_augmented) in enumerate(zip(x_values, y_train_augmented, y_test_augmented)):
    ax.annotate(f'Train: {y_train_augmented:.4f}', (x, y_train_augmented), xytext=(10, 5), textcoords='offset points', ha='left', va='bottom', color='g')
    ax.annotate(f'Test: {y_test_augmented:.4f}', (x, y_test_augmented), xytext=(10, -5), textcoords='offset points', ha='left', va='top', color='y')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x_values = list(Final_Train_accuracy_Base.keys())
y_train_base = list(Final_Train_accuracy_Base.values())
y_test_base = list(Final_Test_accuracy_Base.values())
y_train_augmented = list(Final_Train_accuracy_Augmented.values())
y_test_augmented = list(Final_Test_accuracy_Augmented.values())

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the lines
ax.plot(x_values, y_train_base, label='Train Accuracy (Base)', marker='o', color='r')
ax.plot(x_values, y_test_base, label='Test Accuracy (Base)', marker='o', color='b')
ax.plot(x_values, y_train_augmented, label='Train Accuracy (Augmented)', marker='o', color='g')
ax.plot(x_values, y_test_augmented, label='Test Accuracy (Augmented)', marker='o', color='y')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Add labels and title
ax.set_xlabel('Model Configuration')
ax.set_ylabel('Accuracy')
ax.set_title('Fusion Model Accuracy Comparison')

# Add legend
ax.legend()

# Add annotations
for i, (x, y_train_base, y_test_base) in enumerate(zip(x_values, y_train_base, y_test_base)):
    ax.annotate(f'{y_train_base:.4f}', (x, y_train_base), xytext=(10, 5), textcoords='offset points', ha='left', va='bottom', color='r')
    ax.annotate(f'{y_test_base:.4f}', (x, y_test_base), xytext=(10, -5), textcoords='offset points', ha='left', va='top', color='b')

for i, (x, y_train_augmented, y_test_augmented) in enumerate(zip(x_values, y_train_augmented, y_test_augmented)):
    ax.annotate(f'{y_train_augmented:.4f}', (x, y_train_augmented), xytext=(10, 5), textcoords='offset points', ha='left', va='bottom', color='g')
    ax.annotate(f'{y_test_augmented:.4f}', (x, y_test_augmented), xytext=(10, -5), textcoords='offset points', ha='left', va='top', color='y')

# Show the plot
plt.show()

# %%
RM_Final_Train_accuracy_Augmented={'Accuracy with 1218 Features': 0.9813432835820896,
 'Accuracy with 200 Features': 0.991044776119403,
 'Accuracy with 100 Features': 0.9902985074626866}
RM_Final_Test_accuracy_Augmented={'Accuracy with 1218 Features': 0.8834519572953736,
 'Accuracy with 200 Features': 0.9688612099644128,
 'Accuracy with 100 Features': 0.9670818505338078}

RM_Final_Train_accuracy_Base={'Accuracy with 1218 Features': 0.918429003021148,
 'Accuracy with 200 Features': 0.9335347432024169,
 'Accuracy with 100 Features': 0.9305135951661632}
RM_Final_Test_accuracy_Base={'Accuracy with 1218 Features': 0.7634408602150538,
 'Accuracy with 200 Features': 0.7885304659498208,
 'Accuracy with 100 Features': 0.7670250896057348}

# %%
import matplotlib.pyplot as plt

# Data
x_values = ['Accuracy with 1218 Features', 'Accuracy with 200 Features', 'Accuracy with 100 Features']
y_train_base = list(RM_Final_Train_accuracy_Base.values())
y_test_base = list(RM_Final_Test_accuracy_Base.values())
y_train_augmented = list(RM_Final_Train_accuracy_Augmented.values())
y_test_augmented = list(RM_Final_Test_accuracy_Augmented.values())

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the lines
ax.plot(x_values, y_train_base, label='Train Accuracy (Base)', marker='o', color='r')
ax.plot(x_values, y_test_base, label='Test Accuracy (Base)', marker='o', color='b')
ax.plot(x_values, y_train_augmented, label='Train Accuracy (Augmented)', marker='o', color='g')
ax.plot(x_values, y_test_augmented, label='Test Accuracy (Augmented)', marker='o', color='y')

# Rotate x-axis labels
plt.xticks(rotation=45)

# Add labels and title
ax.set_xlabel('Model Configuration')
ax.set_ylabel('Accuracy')
ax.set_title('Radiomics Model Accuracy Comparison')

# Add legend
ax.legend()

# Add annotations
for i, (x, y_train_base, y_test_base) in enumerate(zip(x_values, y_train_base, y_test_base)):
   ax.annotate(f'{y_train_base:.4f}', (x, y_train_base), xytext=(10, 5), textcoords='offset points', ha='left', va='bottom', color='r')
   ax.annotate(f'{y_test_base:.4f}', (x, y_test_base), xytext=(10, -5), textcoords='offset points', ha='left', va='top', color='b')

for i, (x, y_train_augmented, y_test_augmented) in enumerate(zip(x_values, y_train_augmented, y_test_augmented)):
   ax.annotate(f'{y_train_augmented:.4f}', (x, y_train_augmented), xytext=(10, 5), textcoords='offset points', ha='left', va='bottom', color='g')
   ax.annotate(f'{y_test_augmented:.4f}', (x, y_test_augmented), xytext=(10, -5), textcoords='offset points', ha='left', va='top', color='y')

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score,roc_curve,recall_score,roc_auc_score,auc,confusion_matrix,cohen_kappa_score, f1_score, precision_score,matthews_corrcoef 
from tqdm import tqdm
from sklearn.svm import SVC,LinearSVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectPercentile, f_classif, chi2, SelectFromModel, SelectKBest
from sklearn.feature_selection import RFE
from sklearn.preprocessing import MinMaxScaler
import scipy.stats as stats
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score

# Optional imports for preprocessing and visualization
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# Set the display options to show all columns
pd.set_option('display.max_columns', None)

# %%
df_rm_base=pd.read_csv("./Radiomics_Features_Base.csv")
df_dl_base=pd.read_csv("./Deep_Learning_Features_Base.csv")

df_rm_aug=pd.read_csv("./Radiomics_Feature_Augmented.csv")
df_dl_aug=pd.read_csv("./Deep_Learning_Features_Augmented.csv")

# %%
print(df_rm_base.shape,df_dl_base.shape,df_rm_aug.shape,df_dl_aug.shape)
# Out:
# (1393, 1221) (1393, 129) (5620, 1220) (5620, 129)

# %%
DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import RocCurveDisplay
import pandas as pd
import joblib

# Load your dataset

# Define features and target
# Specify the feature names
X_200 = df_rm_aug[RM_200_top_feature_names]
X_10=df_dl_aug[DL_10_top_feature_names]
X_210_DL_featues= pd.concat([X_200, X_10], axis=1)
#X_220_DL_featues=X_220_DL_featues.drop('Patient_id', axis=1)
y = df_rm_aug['Malignancy']

# Use RandomOverSampler to oversample the minority class
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(X_210_DL_featues, y)

# Standardize the data


# Convert the resampled features and target back to DataFrame for ease of handling
X_resampled_df = pd.DataFrame(X_resampled, columns=X_210_DL_featues.columns)
y_resampled_df = pd.Series(y_resampled, name='Malignancy')

# Combine the resampled features and target back into a DataFrame
df_resampled = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Prepare data for cross-validation
X = df_resampled.drop(columns='Malignancy')
y = df_resampled['Malignancy']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Define the number of folds (K)
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
accuracy_scores = []
best_accuracy = 0
best_model = None

# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}

   # Train the model
model = RandomForestClassifier(random_state=42, **rf_hyperparameters)
model.fit(X_train, y_train)
    
    # Make predictions on the test set
y_pred = model.predict(X_test)
    
    # Evaluate the model
accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
aug_model = RocCurveDisplay.from_estimator(model, X_test, y_test, name='Augmented Model')
plt.show()
# Save the best model
# Out:
# Accuracy: 0.9825
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1082
#            1       0.98      0.98      0.98      1027
#
#     accuracy                           0.98      2109
#    macro avg       0.98      0.98      0.98      2109
# weighted avg       0.98      0.98      0.98      2109
#
# Confusion Matrix:
#  [[1062   20]
#  [  17 1010]]

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
import pandas as pd
import joblib

# Load your dataset

# Define features and target
# Specify the feature names
X_200 = df_rm_base[RM_200_top_feature_names]
X_10=df_dl_base[DL_10_top_feature_names]
X_210_DL_featues= pd.concat([X_200, X_10], axis=1)
#X_220_DL_featues=X_220_DL_featues.drop('Patient_id', axis=1)
y = df_rm_base['Malignancy']

# Use RandomOverSampler to oversample the minority class
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(X_210_DL_featues, y)

# Use RandomOverSampler to oversample the minority class

# Standardize the data


# Convert the resampled features and target back to DataFrame for ease of handling
X_resampled_df = pd.DataFrame(X_resampled, columns=X_210_DL_featues.columns)
y_resampled_df = pd.Series(y_resampled, name='Malignancy')

# Combine the resampled features and target back into a DataFrame
df_resampled = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Prepare data for cross-validation
X = df_resampled.drop(columns='Malignancy')
y = df_resampled['Malignancy']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Define the number of folds (K)
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
accuracy_scores = []
best_accuracy = 0
best_model = None

# Specify hyperparameters
rf_hyperparameters = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}

   # Train the model
model = RandomForestClassifier(random_state=42, **rf_hyperparameters)
model.fit(X_train, y_train)
    
    # Make predictions on the test set
y_pred = model.predict(X_test)
    
    # Evaluate the model
accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
ax = plt.gca()
rfc_disp = RocCurveDisplay.from_estimator(model, X_test, y_test, ax=ax, alpha=0.8, name='Base Model')
aug_model.plot(ax=ax, alpha=0.8)

# Add legend
plt.legend()
plt.show()
# Out:
# Accuracy: 0.9313
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       265
#            1       0.90      0.97      0.93       259
#
#     accuracy                           0.93       524
#    macro avg       0.93      0.93      0.93       524
# weighted avg       0.93      0.93      0.93       524
#
# Confusion Matrix:
#  [[237  28]
#  [  8 251]]

# %%
#To plot 9 different models' AUC curves, you can create a loop and call RocCurveDisplay.from_estimator for each model, passing a unique name for each model. Here's an example of how you can modify the code to achieve this:
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
df_rm_base=pd.read_csv("./Radiomics_Features_Base.csv")
df_dl_base=pd.read_csv("./Deep_Learning_Features_Base.csv")


DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base.drop(columns=['Patient_id','Malignancy','nodule no'])
Y_Base=df_rm_base['Malignancy']
X_128=df_dl_base.drop(columns='Patient_id')
X_20=df_dl_base[DL_20_top_feature_names]
X_10=df_dl_base[DL_10_top_feature_names]
X_200=df_rm_base[RM_200_top_feature_names]
X_100=df_rm_base[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))
performance_matrics={}
# Loop through the models and plot their AUC curves
for name, model_det in models.items():
    X=model_det[0]
    y=model_det[1]
    oversampler = RandomOverSampler(random_state=42)
    X_resampled, y_resampled = oversampler.fit_resample(X, y)

# Use RandomOverSampler to oversample the minority class

# Standardize the data


# Convert the resampled features and target back to DataFrame for ease of handling
    X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
    y_resampled_df = pd.Series(y_resampled, name='Malignancy')

# Combine the resampled features and target back into a DataFrame
    df_resampled = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Prepare data for cross-validation
    X = df_resampled.drop(columns='Malignancy')
    y = df_resampled['Malignancy']
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    rf_hyperparameters = {
        'max_depth': None,
        'max_features': 'sqrt',
        'min_samples_leaf': 1,
        'min_samples_split': 2,
        'n_estimators': 200
        }

   # Train the model
    RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
    RF.fit(X_train, y_train)
    
    # Make predictions on the test set
    y_pred = RF.predict(X_test)
    y_prob = RF.predict_proba(X_test)[:, 1]
    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)
    performance_matrics[name]=[accuracy,precision,recall,f1,auc]
    print(f"Accuracy {name}: {accuracy:.4f}")
    print(f"Precision  {name}: {precision:.4f}")
    print(f"Sensitivity (Recall)  {name}: {recall:.4f}")
    print(f"F1-score  {name}: {f1:.4f}")
    #print("Classification Report:\n", classification_report(y_test, y_pred))
    #print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("="*30)
    
    rfc_disp = RocCurveDisplay.from_estimator(RF, X_test, y_test, ax=ax, alpha=0.8, name=name)

# Add legend
ax.legend() 

# Adjust the plot and display
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Multiple Models with Base Dataset[Oversampled]")
plt.show()
# Out:
# Accuracy Radiomics_1218_Feature: 0.9046
# Precision  Radiomics_1218_Feature: 0.8973
# Sensitivity (Recall)  Radiomics_1218_Feature: 0.9112
# F1-score  Radiomics_1218_Feature: 0.9042
# ==============================
# Accuracy Radiomics_200_Features: 0.9160
# Precision  Radiomics_200_Features: 0.9249
# Sensitivity (Recall)  Radiomics_200_Features: 0.9035
# F1-score  Radiomics_200_Features: 0.9141
# ==============================
# Accuracy Radiomics_100_Features: 0.9198
# Precision  Radiomics_100_Features: 0.9157
# Sensitivity (Recall)  Radiomics_100_Features: 0.9228
# F1-score  Radiomics_100_Features: 0.9192
# ==============================
# Accuracy Fuse_1218_128_Features: 0.9313
# Precision  Fuse_1218_128_Features: 0.8968
# Sensitivity (Recall)  Fuse_1218_128_Features: 0.9730
# F1-score  Fuse_1218_128_Features: 0.9333
# ==============================
# Accuracy Fuse_1218_20_Features: 0.9218
# Precision  Fuse_1218_20_Features: 0.8811
# Sensitivity (Recall)  Fuse_1218_20_Features: 0.9730
# F1-score  Fuse_1218_20_Features: 0.9248
# ==============================
# Accuracy Fuse_1218_10_Features: 0.9332
# Precision  Fuse_1218_10_Features: 0.8972
# Sensitivity (Recall)  Fuse_1218_10_Features: 0.9768
# F1-score  Fuse_1218_10_Features: 0.9353
# ==============================
# Accuracy Fuse_200_128_Features: 0.9313
# Precision  Fuse_200_128_Features: 0.8968
# Sensitivity (Recall)  Fuse_200_128_Features: 0.9730
# F1-score  Fuse_200_128_Features: 0.9333
# ==============================
# Accuracy Fuse_200_20_Features: 0.9237
# Precision  Fuse_200_20_Features: 0.8842
# Sensitivity (Recall)  Fuse_200_20_Features: 0.9730
# F1-score  Fuse_200_20_Features: 0.9265
# ==============================
# Accuracy Fuse_200_10_Features: 0.9313
# Precision  Fuse_200_10_Features: 0.8996
# Sensitivity (Recall)  Fuse_200_10_Features: 0.9691
# F1-score  Fuse_200_10_Features: 0.9331
# ==============================
# Accuracy Fuse_100_128_Features: 0.9351
# Precision  Fuse_100_128_Features: 0.9032
# Sensitivity (Recall)  Fuse_100_128_Features: 0.9730
# F1-score  Fuse_100_128_Features: 0.9368
# ==============================
# Accuracy Fuse_100_20_Features: 0.9179
# Precision  Fuse_100_20_Features: 0.8750
# Sensitivity (Recall)  Fuse_100_20_Features: 0.9730
# F1-score  Fuse_100_20_Features: 0.9214
# ==============================
# Accuracy Fuse_100_10_Features: 0.9332
# Precision  Fuse_100_10_Features: 0.8972
# Sensitivity (Recall)  Fuse_100_10_Features: 0.9768
# F1-score  Fuse_100_10_Features: 0.9353
# ==============================

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
df_rm_base=pd.read_csv("./Radiomics_Features_Base.csv")
df_dl_base=pd.read_csv("./Deep_Learning_Features_Base.csv")


DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_base['Malignancy']
X_128=df_dl_base.drop(columns='Patient_id')
X_20=df_dl_base[DL_20_top_feature_names]
X_10=df_dl_base[DL_10_top_feature_names]
X_200=df_rm_base[RM_200_top_feature_names]
X_100=df_rm_base[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}
performance_matrics={}
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Loop through the models and plot their AUC curves
for name, model_det in models.items():
    X=model_det[0]
    y=model_det[1]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    rf_hyperparameters = {
        'max_depth': None,
        'max_features': 'sqrt',
        'min_samples_leaf': 1,
        'min_samples_split': 2,
        'n_estimators': 200
        }

    RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
    RF.fit(X_train, y_train)
    
    # Make predictions on the test set
    y_pred = RF.predict(X_test)
    y_prob = RF.predict_proba(X_test)[:, 1]
    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)
    performance_matrics[name]=[accuracy,precision,recall,f1,auc]
    print(f"Accuracy {name}: {accuracy:.4f}")
    print(f"Precision  {name}: {precision:.4f}")
    print(f"Sensitivity (Recall)  {name}: {recall:.4f}")
    print(f"F1-score  {name}: {f1:.4f}")
    #print("Classification Report:\n", classification_report(y_test, y_pred))
    #print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("="*30)
    
    rfc_disp = RocCurveDisplay.from_estimator(RF, X_test, y_test, ax=ax, alpha=0.8, name=name)

# Add legend
ax.legend() 

# Adjust the plot and display
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Multiple Models with Base Dataset[without Oversampled]")
plt.show()
# Out:
# Accuracy Radiomics_1218_Feature: 0.7708
# Precision  Radiomics_1218_Feature: 0.5000
# Sensitivity (Recall)  Radiomics_1218_Feature: 0.5000
# F1-score  Radiomics_1218_Feature: 0.2453
# ==============================
# Accuracy Radiomics_200_Features: 0.7708
# Precision  Radiomics_200_Features: 0.5000
# Sensitivity (Recall)  Radiomics_200_Features: 0.5000
# F1-score  Radiomics_200_Features: 0.2857
# ==============================
# Accuracy Radiomics_100_Features: 0.7650
# Precision  Radiomics_100_Features: 0.4545
# Sensitivity (Recall)  Radiomics_100_Features: 0.4545
# F1-score  Radiomics_100_Features: 0.1961
# ==============================
# Accuracy Fuse_1218_128_Features: 0.8940
# Precision  Fuse_1218_128_Features: 0.8209
# Sensitivity (Recall)  Fuse_1218_128_Features: 0.8209
# F1-score  Fuse_1218_128_Features: 0.7483
# ==============================
# Accuracy Fuse_1218_20_Features: 0.8854
# Precision  Fuse_1218_20_Features: 0.8030
# Sensitivity (Recall)  Fuse_1218_20_Features: 0.8030
# F1-score  Fuse_1218_20_Features: 0.7260
# ==============================
# Accuracy Fuse_1218_10_Features: 0.8625
# Precision  Fuse_1218_10_Features: 0.8478
# Sensitivity (Recall)  Fuse_1218_10_Features: 0.8478
# F1-score  Fuse_1218_10_Features: 0.6190
# ==============================
# Accuracy Fuse_200_128_Features: 0.8997
# Precision  Fuse_200_128_Features: 0.8169
# Sensitivity (Recall)  Fuse_200_128_Features: 0.8169
# F1-score  Fuse_200_128_Features: 0.7682
# ==============================
# Accuracy Fuse_200_20_Features: 0.8825
# Precision  Fuse_200_20_Features: 0.7671
# Sensitivity (Recall)  Fuse_200_20_Features: 0.7671
# F1-score  Fuse_200_20_Features: 0.7320
# ==============================
# Accuracy Fuse_200_10_Features: 0.8883
# Precision  Fuse_200_10_Features: 0.8254
# Sensitivity (Recall)  Fuse_200_10_Features: 0.8254
# F1-score  Fuse_200_10_Features: 0.7273
# ==============================
# Accuracy Fuse_100_128_Features: 0.9054
# Precision  Fuse_100_128_Features: 0.8133
# Sensitivity (Recall)  Fuse_100_128_Features: 0.8133
# F1-score  Fuse_100_128_Features: 0.7871
# ==============================
# Accuracy Fuse_100_20_Features: 0.8911
# Precision  Fuse_100_20_Features: 0.7917
# Sensitivity (Recall)  Fuse_100_20_Features: 0.7917
# F1-score  Fuse_100_20_Features: 0.7500
# ==============================
# Accuracy Fuse_100_10_Features: 0.8825
# Precision  Fuse_100_10_Features: 0.7910
# Sensitivity (Recall)  Fuse_100_10_Features: 0.7910
# F1-score  Fuse_100_10_Features: 0.7211
# ==============================

# %% [markdown]
# Augmented Dataset

# %%
#To plot 9 different models' AUC curves, you can create a loop and call RocCurveDisplay.from_estimator for each model, passing a unique name for each model. Here's an example of how you can modify the code to achieve this:
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
df_rm_base=pd.read_csv("./Radiomics_Feature_Augmented.csv")
df_dl_base=pd.read_csv("./Deep_Learning_Features_Augmented.csv")


DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_base['Malignancy']
X_128=df_dl_base.drop(columns='Patient_id')
X_20=df_dl_base[DL_20_top_feature_names]
X_10=df_dl_base[DL_10_top_feature_names]
X_200=df_rm_base[RM_200_top_feature_names]
X_100=df_rm_base[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}
performance_matrics={}
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Loop through the models and plot their AUC curves
for name, model_det in models.items():
    X=model_det[0]
    y=model_det[1]
    oversampler = RandomOverSampler(random_state=42)
    X_resampled, y_resampled = oversampler.fit_resample(X, y)

# Use RandomOverSampler to oversample the minority class

# Standardize the data


# Convert the resampled features and target back to DataFrame for ease of handling
    X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
    y_resampled_df = pd.Series(y_resampled, name='Malignancy')

# Combine the resampled features and target back into a DataFrame
    df_resampled = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Prepare data for cross-validation
    X = df_resampled.drop(columns='Malignancy')
    y = df_resampled['Malignancy']
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    rf_hyperparameters = {
        'max_depth': None,
        'max_features': 'sqrt',
        'min_samples_leaf': 1,
        'min_samples_split': 2,
        'n_estimators': 200
        }

   # Train the model
    RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
    RF.fit(X_train, y_train)
    
    # Make predictions on the test set
    y_pred = RF.predict(X_test)
    
    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print(f"Accuracy {name}: {accuracy:.4f}")
    print(f"Precision  {name}: {precision:.4f}")
    print(f"Sensitivity (Recall)  {name}: {recall:.4f}")
    print(f"F1-score  {name}: {f1:.4f}")
    #print("Classification Report:\n", classification_report(y_test, y_pred))
    #print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("="*30)
    performance_matrics[name]=[accuracy,precision,recall,f1]
    rfc_disp = RocCurveDisplay.from_estimator(RF, X_test, y_test, ax=ax, alpha=0.8, name=name)

# Add legend
ax.legend() 

# Adjust the plot and display
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Multiple Models with Augmented Dataset")
plt.show()
# Out:
# Accuracy Radiomics_1218_Feature: 0.9829
# Precision  Radiomics_1218_Feature: 0.9882
# Sensitivity (Recall)  Radiomics_1218_Feature: 0.9882
# F1-score  Radiomics_1218_Feature: 0.9824
# ==============================
# Accuracy Radiomics_200_Features: 0.9910
# Precision  Radiomics_200_Features: 0.9932
# Sensitivity (Recall)  Radiomics_200_Features: 0.9932
# F1-score  Radiomics_200_Features: 0.9907
# ==============================
# Accuracy Radiomics_100_Features: 0.9915
# Precision  Radiomics_100_Features: 0.9922
# Sensitivity (Recall)  Radiomics_100_Features: 0.9922
# F1-score  Radiomics_100_Features: 0.9912
# ==============================
# Accuracy Fuse_1218_128_Features: 0.9692
# Precision  Fuse_1218_128_Features: 0.9643
# Sensitivity (Recall)  Fuse_1218_128_Features: 0.9643
# F1-score  Fuse_1218_128_Features: 0.9685
# ==============================
# Accuracy Fuse_1218_20_Features: 0.9692
# Precision  Fuse_1218_20_Features: 0.9661
# Sensitivity (Recall)  Fuse_1218_20_Features: 0.9661
# F1-score  Fuse_1218_20_Features: 0.9684
# ==============================
# Accuracy Fuse_1218_10_Features: 0.9772
# Precision  Fuse_1218_10_Features: 0.9776
# Sensitivity (Recall)  Fuse_1218_10_Features: 0.9776
# F1-score  Fuse_1218_10_Features: 0.9766
# ==============================
# Accuracy Fuse_200_128_Features: 0.9649
# Precision  Fuse_200_128_Features: 0.9534
# Sensitivity (Recall)  Fuse_200_128_Features: 0.9534
# F1-score  Fuse_200_128_Features: 0.9644
# ==============================
# Accuracy Fuse_200_20_Features: 0.9654
# Precision  Fuse_200_20_Features: 0.9543
# Sensitivity (Recall)  Fuse_200_20_Features: 0.9543
# F1-score  Fuse_200_20_Features: 0.9649
# ==============================
# Accuracy Fuse_200_10_Features: 0.9825
# Precision  Fuse_200_10_Features: 0.9806
# Sensitivity (Recall)  Fuse_200_10_Features: 0.9806
# F1-score  Fuse_200_10_Features: 0.9820
# ==============================
# Accuracy Fuse_100_128_Features: 0.9583
# Precision  Fuse_100_128_Features: 0.9467
# Sensitivity (Recall)  Fuse_100_128_Features: 0.9467
# F1-score  Fuse_100_128_Features: 0.9577
# ==============================
# Accuracy Fuse_100_20_Features: 0.9611
# Precision  Fuse_100_20_Features: 0.9462
# Sensitivity (Recall)  Fuse_100_20_Features: 0.9462
# F1-score  Fuse_100_20_Features: 0.9607
# ==============================
# Accuracy Fuse_100_10_Features: 0.9734
# Precision  Fuse_100_10_Features: 0.9673
# Sensitivity (Recall)  Fuse_100_10_Features: 0.9673
# F1-score  Fuse_100_10_Features: 0.9729
# ==============================

# %%
performance_matrics
# Out:
# {'Radiomics_1218_Feature': [0.9829302987197724,
#   0.9881773399014778,
#   0.9881773399014778,
#   0.9823702252693438],
#  'Radiomics_200_Features': [0.990990990990991,
#   0.9931506849315068,
#   0.9931506849315068,
#   0.9907271839921913],
#  'Radiomics_100_Features': [0.9914651493598862,
#   0.9921951219512195,
#   0.9921951219512195,
#   0.9912280701754386],
#  'Fuse_1218_128_Features': [0.9691797060218112,
#   0.9642857142857143,
#   0.9642857142857143,
#   0.9684924866698982],
#  'Fuse_1218_20_Features': [0.9691797060218112,
#   0.9660852713178295,
#   0.9660852713178295,
#   0.968431277319087],
#  'Fuse_1218_10_Features': [0.9772403982930299,
#   0.9775609756097561,
#   0.9775609756097561,
#   0.9766081871345029],
#  'Fuse_200_128_Features': [0.9649122807017544,
#   0.9533777354900095,
#   0.9533777354900095,
#   0.9643888354186718],
#  'Fuse_200_20_Features': [0.9653864390706496,
#   0.9542857142857143,
#   0.9542857142857143,
#   0.9648531535869042],
#  'Fuse_200_10_Features': [0.9824561403508771,
#   0.9805825242718447,
#   0.9805825242718447,
#   0.9820126397666504],
#  'Fuse_100_128_Features': [0.9582740635372214,
#   0.9467174119885823,
#   0.9467174119885823,
#   0.9576515880654476],
#  'Fuse_100_20_Features': [0.9611190137505927,
#   0.9461756373937678,
#   0.9461756373937678,
#   0.9606903163950143],
#  'Fuse_100_10_Features': [0.9734471313418682,
#   0.9672762271414822,
#   0.9672762271414822,
#   0.972894482090997]}

# %% [markdown]
# With out Resampling

# %%
#To plot 9 different models' AUC curves, you can create a loop and call RocCurveDisplay.from_estimator for each model, passing a unique name for each model. Here's an example of how you can modify the code to achieve this:
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
df_rm_base=pd.read_csv("./Radiomics_Feature_Augmented.csv")
df_dl_base=pd.read_csv("./Deep_Learning_Features_Augmented.csv")


DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_base['Malignancy']
X_128=df_dl_base.drop(columns='Patient_id')
X_20=df_dl_base[DL_20_top_feature_names]
X_10=df_dl_base[DL_10_top_feature_names]
X_200=df_rm_base[RM_200_top_feature_names]
X_100=df_rm_base[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}
performance_matrics={}
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Loop through the models and plot their AUC curves
for name, model_det in models.items():
    X=model_det[0]
    y=model_det[1]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    rf_hyperparameters = {
        'max_depth': None,
        'max_features': 'sqrt',
        'min_samples_leaf': 1,
        'min_samples_split': 2,
        'n_estimators': 200
        }

   # Train the model
    RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
    RF.fit(X_train, y_train)
    
    # Make predictions on the test set
    y_pred = RF.predict(X_test)
    
    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print(f"Accuracy {name}: {accuracy:.4f}")
    print(f"Precision  {name}: {precision:.4f}")
    print(f"Sensitivity (Recall)  {name}: {precision:.4f}")
    print(f"F1-score  {name}: {f1:.4f}")
    #print("Classification Report:\n", classification_report(y_test, y_pred))
    #print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("="*30)
    performance_matrics[name]=[accuracy,precision,precision,f1]
    rfc_disp = RocCurveDisplay.from_estimator(RF, X_test, y_test, ax=ax, alpha=0.8, name=name)

# Add legend
ax.legend() 

# Adjust the plot and display
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Multiple Models with Augmented Dataset")
plt.show()
# Out:
# Accuracy Radiomics_1218_Feature: 0.9146
# Precision  Radiomics_1218_Feature: 0.9541
# Sensitivity (Recall)  Radiomics_1218_Feature: 0.9541
# F1-score  Radiomics_1218_Feature: 0.7761
# ==============================
# Accuracy Radiomics_200_Features: 0.9495
# Precision  Radiomics_200_Features: 0.9660
# Sensitivity (Recall)  Radiomics_200_Features: 0.9660
# F1-score  Radiomics_200_Features: 0.8782
# ==============================
# Accuracy Radiomics_100_Features: 0.9537
# Precision  Radiomics_100_Features: 0.9703
# Sensitivity (Recall)  Radiomics_100_Features: 0.9703
# F1-score  Radiomics_100_Features: 0.8893
# ==============================
# Accuracy Fuse_1218_128_Features: 0.8776
# Precision  Fuse_1218_128_Features: 0.8578
# Sensitivity (Recall)  Fuse_1218_128_Features: 0.8578
# F1-score  Fuse_1218_128_Features: 0.6705
# ==============================
# Accuracy Fuse_1218_20_Features: 0.8833
# Precision  Fuse_1218_20_Features: 0.8500
# Sensitivity (Recall)  Fuse_1218_20_Features: 0.8500
# F1-score  Fuse_1218_20_Features: 0.6952
# ==============================
# Accuracy Fuse_1218_10_Features: 0.8996
# Precision  Fuse_1218_10_Features: 0.9360
# Sensitivity (Recall)  Fuse_1218_10_Features: 0.9360
# F1-score  Fuse_1218_10_Features: 0.7294
# ==============================
# Accuracy Fuse_200_128_Features: 0.8925
# Precision  Fuse_200_128_Features: 0.8494
# Sensitivity (Recall)  Fuse_200_128_Features: 0.8494
# F1-score  Fuse_200_128_Features: 0.7289
# ==============================
# Accuracy Fuse_200_20_Features: 0.8918
# Precision  Fuse_200_20_Features: 0.8374
# Sensitivity (Recall)  Fuse_200_20_Features: 0.8374
# F1-score  Fuse_200_20_Features: 0.7305
# ==============================
# Accuracy Fuse_200_10_Features: 0.9139
# Precision  Fuse_200_10_Features: 0.9191
# Sensitivity (Recall)  Fuse_200_10_Features: 0.9191
# F1-score  Fuse_200_10_Features: 0.7812
# ==============================
# Accuracy Fuse_100_128_Features: 0.8762
# Precision  Fuse_100_128_Features: 0.8333
# Sensitivity (Recall)  Fuse_100_128_Features: 0.8333
# F1-score  Fuse_100_128_Features: 0.6742
# ==============================
# Accuracy Fuse_100_20_Features: 0.8783
# Precision  Fuse_100_20_Features: 0.8210
# Sensitivity (Recall)  Fuse_100_20_Features: 0.8210
# F1-score  Fuse_100_20_Features: 0.6874
# ==============================
# Accuracy Fuse_100_10_Features: 0.9053
# Precision  Fuse_100_10_Features: 0.9039
# Sensitivity (Recall)  Fuse_100_10_Features: 0.9039
# F1-score  Fuse_100_10_Features: 0.7569
# ==============================

# %% [markdown]
# Base model Oversampling

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
df_rm_base=pd.read_csv("./Radiomics_Features_Base.csv")
df_dl_base=pd.read_csv("./Deep_Learning_Features_Base.csv")


DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_base['Malignancy']
X_128=df_dl_base.drop(columns='Patient_id')
X_20=df_dl_base[DL_20_top_feature_names]
X_10=df_dl_base[DL_10_top_feature_names]
X_200=df_rm_base[RM_200_top_feature_names]
X_100=df_rm_base[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}

performance_metrics = {}
fig, ax = plt.subplots(figsize=(10, 8))
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    accuracy_scores = []
    precision_scores = []
    recall_scores = []
    f1_scores = []
   

    for train_index, test_index in cv.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Apply oversampling on the training data
        oversampler = RandomOverSampler(random_state=42)
        X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train_resampled, y_train_resampled)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)
        precision_scores.append(precision)
        recall_scores.append(recall)
        f1_scores.append(f1)
        rfc_disp = RocCurveDisplay.from_estimator(RF, X_test, y_test, ax=ax, alpha=0.8, name=name)
    mean_accuracy = np.mean(accuracy_scores)
    mean_precision = np.mean(precision_scores)
    mean_recall = np.mean(recall_scores)
    mean_f1 = np.mean(f1_scores)

    print(f"Accuracy {name}: {mean_accuracy:.4f}")
    print(f"Precision {name}: {mean_precision:.4f}")
    print(f"Sensitivity (Recall) {name}: {mean_recall:.4f}")
    print(f"F1-score {name}: {mean_f1:.4f}")
    print("=" * 30)

    performance_metrics[name] = {
        'accuracy': mean_accuracy,
        'precision': mean_precision,
        'recall': mean_recall,
        'f1': mean_f1
    }
    

# Add legend
ax.legend() 

# Adjust the plot and display
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Multiple Models with Augmented Dataset")
plt.show()
# Out:
# Accuracy Radiomics_1218_Feature: 0.7351
# Precision Radiomics_1218_Feature: 0.4229
# Sensitivity (Recall) Radiomics_1218_Feature: 0.1764
# F1-score Radiomics_1218_Feature: 0.2476
# ==============================
# Accuracy Radiomics_200_Features: 0.7294
# Precision Radiomics_200_Features: 0.4029
# Sensitivity (Recall) Radiomics_200_Features: 0.1909
# F1-score Radiomics_200_Features: 0.2582
# ==============================
# Accuracy Radiomics_100_Features: 0.7380
# Precision Radiomics_100_Features: 0.4408
# Sensitivity (Recall) Radiomics_100_Features: 0.2111
# F1-score Radiomics_100_Features: 0.2845
# ==============================
# Accuracy Fuse_1218_128_Features: 0.8665
# Precision Fuse_1218_128_Features: 0.7529
# Sensitivity (Recall) Fuse_1218_128_Features: 0.6880
# F1-score Fuse_1218_128_Features: 0.7183
# ==============================
# Accuracy Fuse_1218_20_Features: 0.8572
# Precision Fuse_1218_20_Features: 0.7264
# Sensitivity (Recall) Fuse_1218_20_Features: 0.6820
# F1-score Fuse_1218_20_Features: 0.7034
# ==============================
# Accuracy Fuse_1218_10_Features: 0.8363
# Precision Fuse_1218_10_Features: 0.7347
# Sensitivity (Recall) Fuse_1218_10_Features: 0.5320
# F1-score Fuse_1218_10_Features: 0.6164
# ==============================
# Accuracy Fuse_200_128_Features: 0.8837
# Precision Fuse_200_128_Features: 0.7857
# Sensitivity (Recall) Fuse_200_128_Features: 0.7313
# F1-score Fuse_200_128_Features: 0.7574
# ==============================
# Accuracy Fuse_200_20_Features: 0.8643
# Precision Fuse_200_20_Features: 0.7299
# Sensitivity (Recall) Fuse_200_20_Features: 0.7198
# F1-score Fuse_200_20_Features: 0.7246
# ==============================
# Accuracy Fuse_200_10_Features: 0.8622
# Precision Fuse_200_10_Features: 0.7444
# Sensitivity (Recall) Fuse_200_10_Features: 0.6793
# F1-score Fuse_200_10_Features: 0.7103
# ==============================
# Accuracy Fuse_100_128_Features: 0.8873
# Precision Fuse_100_128_Features: 0.7839
# Sensitivity (Recall) Fuse_100_128_Features: 0.7543
# F1-score Fuse_100_128_Features: 0.7687
# ==============================
# Accuracy Fuse_100_20_Features: 0.8665
# Precision Fuse_100_20_Features: 0.7407
# Sensitivity (Recall) Fuse_100_20_Features: 0.7111
# F1-score Fuse_100_20_Features: 0.7254
# ==============================
# Accuracy Fuse_100_10_Features: 0.8636
# Precision Fuse_100_10_Features: 0.7456
# Sensitivity (Recall) Fuse_100_10_Features: 0.6851
# F1-score Fuse_100_10_Features: 0.7139
# ==============================

# %%
models_to_plot = ['Radiomics_1218_Feature', 'Radiomics_200_Features', 'Fuse_1218_128_Features']
line_styles = ['-', '--', '-.']  # List of line styles for each model

performance_metrics = {}
fig, ax = plt.subplots(figsize=(10, 8))
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, model_det, line_style in zip(models_to_plot, [models[m] for m in models_to_plot], line_styles):
    X = model_det[0]
    y = model_det[1]
    accuracy_scores = []
    precision_scores = []
    recall_scores = []
    f1_scores = []

    for train_index, test_index in cv.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Apply oversampling on the training data
        oversampler = RandomOverSampler(random_state=42)
        X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train_resampled, y_train_resampled)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)
        precision_scores.append(precision)
        recall_scores.append(recall)
        f1_scores.append(f1)
        rfc_disp = RocCurveDisplay.from_estimator(RF, X_test, y_test, ax=ax, alpha=0.8, linestyle=line_style, name=name)

    mean_accuracy = np.mean(accuracy_scores)
    mean_precision = np.mean(precision_scores)
    mean_recall = np.mean(recall_scores)
    mean_f1 = np.mean(f1_scores)

    print(f"Accuracy {name}: {mean_accuracy:.4f}")
    print(f"Precision {name}: {mean_precision:.4f}")
    print(f"Sensitivity (Recall) {name}: {mean_recall:.4f}")
    print(f"F1-score {name}: {mean_f1:.4f}")
    print("=" * 30)

    performance_metrics[name] = {
        'accuracy': mean_accuracy,
        'precision': mean_precision,
        'recall': mean_recall,
        'f1': mean_f1
    }

# Add legend
ax.legend()

# Adjust the plot and display
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Selected Models with Augmented Dataset")
plt.show()
# Out:
# Accuracy Radiomics_1218_Feature: 0.7351
# Precision Radiomics_1218_Feature: 0.4229
# Sensitivity (Recall) Radiomics_1218_Feature: 0.1764
# F1-score Radiomics_1218_Feature: 0.2476
# ==============================
# Accuracy Radiomics_200_Features: 0.7294
# Precision Radiomics_200_Features: 0.4029
# Sensitivity (Recall) Radiomics_200_Features: 0.1909
# F1-score Radiomics_200_Features: 0.2582
# ==============================
# Accuracy Fuse_1218_128_Features: 0.8665
# Precision Fuse_1218_128_Features: 0.7529
# Sensitivity (Recall) Fuse_1218_128_Features: 0.6880
# F1-score Fuse_1218_128_Features: 0.7183
# ==============================

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
df_rm_base=pd.read_csv("./Radiomics_Feature_Augmented.csv")
df_dl_base=pd.read_csv("./Deep_Learning_Features_Augmented.csv")


DL_20_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127', '83', '107', '36', '5', '61', '103', '35', '106', '57', '81']
DL_10_top_feature_names=['85', '105', '63', '118', '84', '20', '30', '32', '45', '127']

RM_200_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis', 'wavelet-LHL_firstorder_Energy', 'log-sigma-3-0-mm-3D_glcm_DifferenceEntropy', 'wavelet-LLL_firstorder_Energy', 'log-sigma-5-0-mm-3D_glcm_MaximumProbability', 'log-sigma-4-0-mm-3D_firstorder_10Percentile', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glrlm_RunLengthNonUniformity', 'wavelet-LLH_glcm_Idn', 'log-sigma-5-0-mm-3D_glszm_GrayLevelVariance', 'original_glcm_Contrast', 'wavelet-HLL_firstorder_10Percentile', 'log-sigma-3-0-mm-3D_firstorder_Skewness', 'log-sigma-3-0-mm-3D_gldm_DependenceEntropy', 'wavelet-LLL_gldm_HighGrayLevelEmphasis', 'wavelet-HLL_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Variance', 'log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance', 'wavelet-LLL_firstorder_Variance', 'log-sigma-4-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'wavelet-LLL_firstorder_TotalEnergy', 'log-sigma-1-0-mm-3D_firstorder_Maximum', 'log-sigma-4-0-mm-3D_glrlm_RunPercentage', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_ZonePercentage', 'wavelet-LLH_glcm_InverseVariance', 'log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Idn', 'wavelet-LLH_firstorder_Range', 'log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-HLL_firstorder_Range', 'log-sigma-4-0-mm-3D_firstorder_Mean', 'log-sigma-5-0-mm-3D_firstorder_Maximum', 'original_firstorder_Range', 'log-sigma-4-0-mm-3D_glrlm_RunVariance', 'log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_glcm_Imc1', 'wavelet-LLH_glcm_Correlation', 'log-sigma-5-0-mm-3D_gldm_GrayLevelVariance', 'wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_SmallDependenceEmphasis', 'wavelet-HHH_glrlm_LongRunEmphasis', 'wavelet-LLL_firstorder_Range', 'log-sigma-3-0-mm-3D_firstorder_10Percentile', 'log-sigma-5-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'original_firstorder_MeanAbsoluteDeviation', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_glcm_ClusterShade', 'log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_glszm_ZonePercentage', 'log-sigma-1-0-mm-3D_firstorder_Range', 'wavelet-LLL_firstorder_Skewness', 'log-sigma-3-0-mm-3D_firstorder_Mean', 'original_shape_Maximum3DDiameter', 'log-sigma-4-0-mm-3D_firstorder_InterquartileRange', 'original_shape_MinorAxisLength', 'wavelet-LLL_glrlm_HighGrayLevelRunEmphasis', 'wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Minimum', 'log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-2-0-mm-3D_firstorder_Variance', 'log-sigma-4-0-mm-3D_firstorder_Range', 'log-sigma-3-0-mm-3D_glcm_ClusterTendency', 'original_glcm_ClusterTendency', 'log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-HLL_firstorder_Variance', 'wavelet-LLH_firstorder_Maximum', 'log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis', 'wavelet-LLH_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis', 'wavelet-LLH_gldm_GrayLevelNonUniformity', 'log-sigma-5-0-mm-3D_glcm_SumSquares', 'log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-4-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LHL_glcm_DifferenceVariance', 'wavelet-LHL_glcm_ClusterProminence', 'log-sigma-5-0-mm-3D_glcm_InverseVariance', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Minimum', 'log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'log-sigma-3-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-1-0-mm-3D_glcm_Idm', 'wavelet-HLH_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance', 'original_glcm_SumEntropy', 'wavelet-LHL_glcm_Id', 'log-sigma-1-0-mm-3D_gldm_GrayLevelVariance']
RM_100_top_feature_names=['log-sigma-5-0-mm-3D_firstorder_Range', 'wavelet-HLH_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'original_shape_Maximum2DDiameterColumn', 'log-sigma-5-0-mm-3D_glrlm_RunVariance', 'log-sigma-4-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis', 'wavelet-LHL_gldm_DependenceNonUniformity', 'log-sigma-5-0-mm-3D_firstorder_InterquartileRange', 'original_shape_LeastAxisLength', 'log-sigma-3-0-mm-3D_firstorder_TotalEnergy', 'log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'wavelet-LLH_firstorder_TotalEnergy', 'log-sigma-3-0-mm-3D_firstorder_Range', 'original_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_TotalEnergy', 'wavelet-LHL_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis', 'original_glrlm_RunEntropy', 'log-sigma-4-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-LHL_glcm_DifferenceEntropy', 'wavelet-LHH_firstorder_TotalEnergy', 'log-sigma-4-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-4-0-mm-3D_glcm_Imc1', 'log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_firstorder_Energy', 'wavelet-LHL_glcm_Idmn', 'wavelet-LLL_firstorder_Minimum', 'wavelet-LLH_firstorder_Energy', 'log-sigma-5-0-mm-3D_glrlm_RunEntropy', 'wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Minimum', 'log-sigma-4-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis', 'wavelet-HHH_glrlm_RunLengthNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_Median', 'log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized', 'log-sigma-5-0-mm-3D_firstorder_Kurtosis', 'wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-5-0-mm-3D_glcm_Idm', 'wavelet-LLH_glrlm_ShortRunEmphasis', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'original_shape_Maximum2DDiameterRow', 'wavelet-LLL_firstorder_Maximum', 'log-sigma-2-0-mm-3D_firstorder_10Percentile', 'original_shape_Flatness', 'log-sigma-5-0-mm-3D_firstorder_Variance', 'original_firstorder_TotalEnergy', 'log-sigma-2-0-mm-3D_firstorder_Energy', 'log-sigma-3-0-mm-3D_firstorder_90Percentile', 'original_shape_SurfaceVolumeRatio', 'log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'wavelet-LHL_glcm_Contrast', 'log-sigma-4-0-mm-3D_glszm_LargeAreaEmphasis', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'wavelet-HLL_glrlm_GrayLevelNonUniformity', 'wavelet-LHH_glszm_ZonePercentage', 'log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis', 'wavelet-LLL_gldm_DependenceNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'wavelet-LLH_glcm_DifferenceAverage', 'wavelet-LLL_gldm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_firstorder_RootMeanSquared', 'wavelet-HLL_firstorder_Mean', 'log-sigma-4-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'log-sigma-3-0-mm-3D_firstorder_Kurtosis', 'log-sigma-4-0-mm-3D_glcm_JointEnergy', 'original_shape_Maximum2DDiameterSlice', 'log-sigma-1-0-mm-3D_firstorder_90Percentile', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'wavelet-HLL_firstorder_InterquartileRange', 'wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_firstorder_InterquartileRange', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-4-0-mm-3D_glrlm_LongRunEmphasis', 'log-sigma-2-0-mm-3D_firstorder_Median', 'log-sigma-4-0-mm-3D_glszm_GrayLevelNonUniformity', 'wavelet-HLL_firstorder_Energy', 'log-sigma-4-0-mm-3D_glcm_Correlation', 'original_firstorder_Minimum', 'wavelet-LHH_gldm_DependenceNonUniformity', 'wavelet-LLH_glcm_Idm', 'log-sigma-5-0-mm-3D_firstorder_Skewness', 'wavelet-LLH_glcm_Imc2', 'wavelet-LHL_glcm_MaximumProbability', 'wavelet-HHH_glrlm_GrayLevelNonUniformity', 'wavelet-HLH_glrlm_GrayLevelNonUniformity', 'log-sigma-4-0-mm-3D_firstorder_Median', 'wavelet-LLL_firstorder_Kurtosis', 'log-sigma-5-0-mm-3D_firstorder_90Percentile', 'log-sigma-4-0-mm-3D_firstorder_Kurtosis']

X_1218=df_rm_base.drop(columns=['Patient_id','Malignancy'])
Y_Base=df_rm_base['Malignancy']
X_128=df_dl_base.drop(columns='Patient_id')
X_20=df_dl_base[DL_20_top_feature_names]
X_10=df_dl_base[DL_10_top_feature_names]
X_200=df_rm_base[RM_200_top_feature_names]
X_100=df_rm_base[RM_100_top_feature_names]
# List of model names
models = {
    'Radiomics_1218_Feature': [ X_1218,Y_Base],
    'Radiomics_200_Features': [ X_200,Y_Base],
    'Radiomics_100_Features': [ X_100,Y_Base],
    'Fuse_1218_128_Features': [ pd.concat([X_1218, X_128], axis=1),Y_Base],
    'Fuse_1218_20_Features': [ pd.concat([X_1218, X_20], axis=1),Y_Base],
    'Fuse_1218_10_Features': [ pd.concat([X_1218, X_10], axis=1),Y_Base],
    'Fuse_200_128_Features': [ pd.concat([X_200, X_128], axis=1),Y_Base],
    'Fuse_200_20_Features': [ pd.concat([X_200, X_20], axis=1),Y_Base],
    'Fuse_200_10_Features': [ pd.concat([X_200, X_10], axis=1),Y_Base],
    'Fuse_100_128_Features': [ pd.concat([X_100, X_128], axis=1),Y_Base],
    'Fuse_100_20_Features': [ pd.concat([X_100, X_20], axis=1),Y_Base],
    'Fuse_100_10_Features': [ pd.concat([X_100, X_10], axis=1),Y_Base]
}

performance_metrics = {}
fig, ax = plt.subplots(figsize=(10, 8))
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, model_det in models.items():
    X = model_det[0]
    y = model_det[1]
    accuracy_scores = []
    precision_scores = []
    recall_scores = []
    f1_scores = []
   

    for train_index, test_index in cv.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Apply oversampling on the training data
        oversampler = RandomOverSampler(random_state=42)
        X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

        # Standardize the data if needed

        # Train the model
        RF = RandomForestClassifier(random_state=42, **rf_hyperparameters)
        RF.fit(X_train_resampled, y_train_resampled)

        # Make predictions on the test set
        y_pred = RF.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        accuracy_scores.append(accuracy)
        precision_scores.append(precision)
        recall_scores.append(recall)
        f1_scores.append(f1)
        rfc_disp = RocCurveDisplay.from_estimator(RF, X_test, y_test, ax=ax, alpha=0.8, name=name)
    mean_accuracy = np.mean(accuracy_scores)
    mean_precision = np.mean(precision_scores)
    mean_recall = np.mean(recall_scores)
    mean_f1 = np.mean(f1_scores)

    print(f"Accuracy {name}: {mean_accuracy:.4f}")
    print(f"Precision {name}: {mean_precision:.4f}")
    print(f"Sensitivity (Recall) {name}: {mean_recall:.4f}")
    print(f"F1-score {name}: {mean_f1:.4f}")
    print("=" * 30)

    performance_metrics[name] = {
        'accuracy': mean_accuracy,
        'precision': mean_precision,
        'recall': mean_recall,
        'f1': mean_f1
    }
    

# Add legend
ax.legend() 

# Adjust the plot and display
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Multiple Models with Augmented Dataset")
plt.show()
# Out:
# Accuracy Radiomics_1218_Feature: 0.9367
# Precision Radiomics_1218_Feature: 0.9535
# Sensitivity (Recall) Radiomics_1218_Feature: 0.7848
# F1-score Radiomics_1218_Feature: 0.8607
# ==============================
# Accuracy Radiomics_200_Features: 0.9653
# Precision Radiomics_200_Features: 0.9700
# Sensitivity (Recall) Radiomics_200_Features: 0.8888
# F1-score Radiomics_200_Features: 0.9274
# ==============================
# Accuracy Radiomics_100_Features: 0.9671
# Precision Radiomics_100_Features: 0.9722
# Sensitivity (Recall) Radiomics_100_Features: 0.8938
# F1-score Radiomics_100_Features: 0.9313
# ==============================
# Accuracy Fuse_1218_128_Features: 0.9037
# Precision Fuse_1218_128_Features: 0.8899
# Sensitivity (Recall) Fuse_1218_128_Features: 0.7014
# F1-score Fuse_1218_128_Features: 0.7840
# ==============================
# Accuracy Fuse_1218_20_Features: 0.9028
# Precision Fuse_1218_20_Features: 0.8912
# Sensitivity (Recall) Fuse_1218_20_Features: 0.6957
# F1-score Fuse_1218_20_Features: 0.7812
# ==============================
# Accuracy Fuse_1218_10_Features: 0.9205
# Precision Fuse_1218_10_Features: 0.9364
# Sensitivity (Recall) Fuse_1218_10_Features: 0.7313
# F1-score Fuse_1218_10_Features: 0.8211
# ==============================
# Accuracy Fuse_200_128_Features: 0.9077
# Precision Fuse_200_128_Features: 0.8771
# Sensitivity (Recall) Fuse_200_128_Features: 0.7328
# F1-score Fuse_200_128_Features: 0.7981
# ==============================
# Accuracy Fuse_200_20_Features: 0.9137
# Precision Fuse_200_20_Features: 0.8834
# Sensitivity (Recall) Fuse_200_20_Features: 0.7541
# F1-score Fuse_200_20_Features: 0.8135
# ==============================
# Accuracy Fuse_200_10_Features: 0.9329
# Precision Fuse_200_10_Features: 0.9336
# Sensitivity (Recall) Fuse_200_10_Features: 0.7876
# F1-score Fuse_200_10_Features: 0.8543
# ==============================
# Accuracy Fuse_100_128_Features: 0.8916
# Precision Fuse_100_128_Features: 0.8523
# Sensitivity (Recall) Fuse_100_128_Features: 0.6857
# F1-score Fuse_100_128_Features: 0.7592
# ==============================
# Accuracy Fuse_100_20_Features: 0.8943
# Precision Fuse_100_20_Features: 0.8486
# Sensitivity (Recall) Fuse_100_20_Features: 0.7021
# F1-score Fuse_100_20_Features: 0.7681
# ==============================
# Accuracy Fuse_100_10_Features: 0.9206
# Precision Fuse_100_10_Features: 0.9095
# Sensitivity (Recall) Fuse_100_10_Features: 0.7577
# F1-score Fuse_100_10_Features: 0.8264
# ==============================
